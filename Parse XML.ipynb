# %%
import logging

# create logger
alogger = logging.getLogger(__name__)
alogger.setLevel(logging.DEBUG)

# create console handler and set level to debug
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)

# create formatter
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# add formatter to ch
ch.setFormatter(formatter)
# add ch to logger
alogger.addHandler(ch)

# initialization: 
alogger.setLevel(logging.WARNING)

# %%
alogger.setLevel(logging.WARNING)
from subprocess import check_output
def graphs2phones(s): 
    """
        Graphemes to Phonemes: 
        Takes a sentence, returns an array of graphemes strings (one per number of words in original sentence)
        Example(s): 
        > graphs2phones('hello world bla and ble')
        > graphs2phones(' wasuuuppp!')
    """
    phs = check_output(["speak", "-q", "-x",'-v', 'en-us',s]).decode('utf-8')
    logger.debug("Return {} strings: {}".format(len(phs.split()), phs))
    return [w for w in phs.strip().split(" ") if w != ' ']

from timeit import default_timer as timer
def take_time(code_snippet_as_string):
    """
        Measures the time it takes to execute the code snippet
        provided as string. 
        Returns: the value of the invocation + number of seconds it took. 
        Example(s): 
        > r, secs = take_time("2 + 2")
        > print("result = {}, time = {} secs".format(r, secs))
    """
    start = timer()
    r = eval(code_snippet_as_string)
    end = timer()
    return (r, end - start)


def key_value(i, phonemes_strs_augm, words_in_sent):
    if len(i) == 1:
        try:
            return (phonemes_strs_augm[i[0]], words_in_sent[math.floor(i[0]/2)])
        except IndexError as e:
            logger.error("Trying to do 'phonemes_strs_augm[i[0]]' :: ")
            logger.error("i[0] = {}".format(i[0]))
            logger.error("phonemes_strs_augm = {}".format(phonemes_strs_augm))
            logger.error("Trying to do 'words_in_sent[math.floor(i[0]/2)]' :: ")
            logger.error("math.floor(i[0]/2) = {}".format(math.floor(i[0]/2)))
            logger.error("words_in_sent = {}".format(words_in_sent))
            raise e
    else:
        return (' '.join(phonemes_strs_augm[i[0]:i[1] + 1]), words_in_sent[int(i[1]/2 - 1)])

def group_contiguous(idxs_phonemes_strs_orig):
    """
        Given a list of indexes produces a list of tuples, where a tuple in a certain position
        has 2 elements iif the indexes are contiguous.
        Example: 
        > group_contiguous([1, 2, 3, 5, 6, 8, 9])
        [(1,2), (3), (5), (6), (8,9)]
        Notice that if more than 2 elements are contiguous, they will be split.
        (eg, in the example above, (1,2,3) was converted to (1,2), (3)) 
    """
    idxs_phonemes_strs = idxs_phonemes_strs_orig
    r = []
    while len(idxs_phonemes_strs) > 0:
        if len(idxs_phonemes_strs) > 1 and (idxs_phonemes_strs[0] + 1 == idxs_phonemes_strs[1]):
            r += [[idxs_phonemes_strs[0], idxs_phonemes_strs[1]]]
            idxs_phonemes_strs = idxs_phonemes_strs[2:]
        else:
            r += [[idxs_phonemes_strs[0]]]
            idxs_phonemes_strs = idxs_phonemes_strs[1:]
    return r
    
    
import functools
    
def graphemes_to_phonemes(words_in_sent):
    """
        Takes a list of words and returns a list of tuples
        (grapheme: phoneme)
        Example:
        > graphemes_to_phonemes(["luis", "papa"])
        [('luis', "lj'u:Iz"), ('papa', "pa#p'A:")]
    """
    MAX_LENGTH_TO_SPEAK = 10 # if I give more than this, espeak fails to do a good job 
    # First step: generate all sounds of words as if they were "alone" (ie, not in a sentence)
    # We want to avoid a combination of words making only 1 sound
    # For example (depending on accent): "what's up?"
    # So in order to do that we'll introduce a word with a unique sound between the words, 
    # generate phonemes and then process them smartly: 
    # separator for words in sentence 
    separator = {"str": "XXX"}
    separator["sound"] = ''.join(graphs2phones(separator["str"]))    
    # 
    how_many_words = len(words_in_sent)
    num_batches = (how_many_words // MAX_LENGTH_TO_SPEAK) + int(how_many_words % MAX_LENGTH_TO_SPEAK != 0)
    result_dict = [] # {}
    for i in range(num_batches):
        logger.debug("{}: {} to {}".format(i, i * MAX_LENGTH_TO_SPEAK, (i + 1)*MAX_LENGTH_TO_SPEAK))
        words_in_batch = words_in_sent[i * MAX_LENGTH_TO_SPEAK: (i + 1)*MAX_LENGTH_TO_SPEAK]
        logger.debug("words_in_batch = {}".format(words_in_batch))
        sent_augm = ' '.join([w1 + ' ' + w2 for w1, w2 in list(zip([separator["str"]]*len(words_in_batch), words_in_batch))]) + " " + separator["str"]
        logger.debug("sent_augm = {}".format(sent_augm))
        phonemes_strs_augm = graphs2phones(sent_augm)
        logger.debug("phonemes_strs_augm = {}".format(phonemes_strs_augm))
        # there we go: all (indexes of) sounds that we are interested in. 
        seps_idxs = [i for i,v in enumerate(phonemes_strs_augm) if v.endswith(separator["sound"])]
        logger.debug("seps_idxs = {}".format(seps_idxs))
        how_many_separators = len(seps_idxs)
        logger.debug("how_many_separators = {}".format(how_many_separators))

        all_sounds = list(map(
            lambda t: ' '.join(phonemes_strs_augm[t[0] + 1: t[1]]),
            list(zip(seps_idxs[:-1], seps_idxs[1:]))))
        logger.debug("all sounds = {}".format(all_sounds))
        result_dict += list(zip(words_in_batch, all_sounds))
    return result_dict
      
    
def dict_phonemes_to_graphemes(words_in_sent) -> dict:
    as_phon_graph_list = graphemes_to_phonemes(words_in_sent)
    return {ph: graph for (graph, ph) in as_phon_graph_list}

# %%
graphemes_to_phonemes(words_in_sent = "this is one sentence".split())
# Out:
# [('this', 'DIs'), ('is', 'Iz'), ('one', "w'Vn"), ('sentence', "s'Ent#@ns")]

# %%
import re

# A custom function to clean the text before sending it into the vectorizer
def clean_text(text):
    # get rid of newlines
    text = text.strip().replace("\n", " ").replace("\r", " ").replace("&#039;", "'").replace("&quot;", "\"")
    
    # replace twitter @mentions
#     mentionFinder = re.compile(r"@[a-z0-9_]{1,15}", re.IGNORECASE)
#     text = mentionFinder.sub("@MENTION", text)
    
    # replace HTML symbols
    text = text.replace("&amp;", "and").replace("&gt;", ">").replace("&lt;", "<").replace("<br>", " ").replace("<BR>", " ")
    
#     # lowercase
#     text = text.lower()

    return text

# %%
print(clean_text('HELLO<br> world'))
print(clean_text("I've been better"))
print(clean_text("I&#039;ve been better"))
print(clean_text("I&#039;ve been &quot;better&quot;"))
# Out:
# HELLO  world
# I've been better
# I've been better
# I've been "better"

# %%
import xmltodict
from typing import List, Dict
class Formspring_Data_Parser():
    
    def __init__(self, path_to_xml):
        with open(path_to_xml) as fd:
            self.path = path_to_xml
            self.doc = xmltodict.parse(fd.read())

    def posts_for_id(self, an_id: int) -> List:
        r = self.doc['dataset']['FORMSPRINGID'][an_id]['POST']
        # is this a list or a dict?
        try:
            r[0]  # wil this throw an Exception?
            return r
        except:
            return list([r])

    def questions_answers_labels(self, an_id: int)->List[Dict]:
        some_posts = self.posts_for_id(an_id)
        r = []
        for post in some_posts:
            q_and_a_orig = post['TEXT']
            logger.debug("q and a orig = '{}'".format(q_and_a_orig))
            q_and_a = clean_text(post['TEXT'])
            logger.debug("q and a = '{}'".format(q_and_a))
            # parse question 
            beg_q = q_and_a.index("Q:") + 2
            end_q = q_and_a.index("A:")
            the_q_raw = q_and_a[beg_q:end_q].strip()
            graphs_and_phons = graphemes_to_phonemes(words_in_sent = the_q_raw.split())
            the_q_as_sounds = ' '.join([ph for _, ph in graphs_and_phons])
            the_q = []
            for s in the_q_as_sounds.split():
                try:
                    the_q.append(mw.sound_to_word(s))
                except:
                    logger.debug("sound '{}' is not recognized".format(s))
                    the_q.append('UNKNOWN')
            the_q = ' '.join(the_q)
            # parse answer 
            the_a = q_and_a[end_q + 2:].strip()
            logger.debug("QUESTION = '{}', ANSWER = '{}'".format(the_q, the_a))
            raw_labels = [lab['ANSWER'] for lab in post['LABELDATA']]
            logger.debug("raw labels = {}".format(raw_labels))
            labels = list(map(lambda txt: txt.lower(), [lab for lab in raw_labels if lab is not None]))
            all_votes_as_yes = [l for l in labels if l == 'yes']
            is_threat = (len(all_votes_as_yes) / len(labels)) >= 0.5
            r.append({
                "txt_orig": q_and_a_orig,
                "question_raw": the_q_raw,
                "question": the_q,
                "question_as_sounds": the_q_as_sounds, 
                "answer_raw": the_a,
                "answer": the_a,
                "answer_as_sounds": the_a, 
                "labels": labels,
                "threat": is_threat
            })
#             r.append({
#                 "orig": {
#                     "txt_orig": q_and_a_orig,
#                     "question_raw": the_q_raw,
#                     "answer_raw": the_a,
#                 }, 
#                 "question": {
#                     "question": the_q,
#                     "question_as_sounds": the_q_as_sounds, 
#                 }, 
#                 "answer": {
#                     "answer": the_a,
#                     "answer_as_sounds": the_a, 
#                 },
#                 "sentiment": {
#                     "labels": labels,
#                     "threat": is_threat
#                 }
#             })
        return r

# %%
xml_file_name = '/Users/luisd/Downloads/FormspringLabeledForCyberbullying/XMLMergedFile.xml'

parser = Formspring_Data_Parser(xml_file_name)

# %%
# alogger.setLevel(logging.DEBUG) # verbose 
alogger.setLevel(logging.WARNING) # silent 
all_of_them = parser.questions_answers_labels(an_id = 1)
all_of_them
# Out:
# [{'answer': '</3 ? haha jk! <33',
#   'answer_as_sounds': '</3 ? haha jk! <33',
#   'answer_raw': '</3 ? haha jk! <33',
#   'labels': ['no', 'no', 'no'],
#   'question': '----------------------------------------------------------_3',
#   'question_as_sounds': "_:_:Tr'i:_!",
#   'question_raw': '<3',
#   'threat': False,
#   'txt_orig': 'Q: <3<br>A: </3 ? haha jk! <33'},
#  {'answer': 'Really?!?! Thanks?! haha',
#   'answer_as_sounds': 'Really?!?! Thanks?! haha',
#   'answer_raw': 'Really?!?! Thanks?! haha',
#   'labels': ['no', 'no', 'no'],
#   'question': 'UNKNOWN ángel _You Duh UNKNOWN',
#   'question_as_sounds': "_:_:h'eI 'eIndZ@L ju: d'V s'Eksi",
#   'question_raw': '"hey angel  you duh sexy"',
#   'threat': False,
#   'txt_orig': 'Q: &quot;hey angel  you duh sexy&quot;<br>A: Really?!?! Thanks?! haha'},
#  {'answer': ';(',
#   'answer_as_sounds': ';(',
#   'answer_raw': ';(',
#   'labels': ['no', 'no', 'no'],
#   'question': '',
#   'question_as_sounds': '',
#   'question_raw': '(:',
#   'threat': False,
#   'txt_orig': 'Q: (:<br>A: ;('},
#  {'answer': '*RAWR*?',
#   'answer_as_sounds': '*RAWR*?',
#   'answer_raw': '*RAWR*?',
#   'labels': ['no', 'no', 'no'],
#   'question': '***************************************************** UNKNOWN *****************************************************',
#   'question_as_sounds': "'ast3r,Iska#st3r,Iska#st3r,Isk mI2;'oUw@ 'ast3r,Iska#st3r,Iska#st3r,Isk",
#   'question_raw': '******************MEOWWW*************************',
#   'threat': False,
#   'txt_orig': 'Q: ******************MEOWWW*************************<br>A: *RAWR*?'},
#  {'answer': 'Sure! Like tell me wht u wnna know?! Like wht do you use?!',
#   'answer_as_sounds': 'Sure! Like tell me wht u wnna know?! Like wht do you use?!',
#   'answer_raw': 'Sure! Like tell me wht u wnna know?! Like wht do you use?!',
#   'labels': ['no', 'no', 'no'],
#   'question': "ANY MAKEUP TIPPS ▪_i succ _At DOING MY' MAKEUP Loll",
#   'question_as_sounds': ",Eni; m'eIkVp t'Ips\n 'aI s'Vk at d,u:I2N maI m'eIkVp l'0l",
#   'question_raw': 'any makeup tips? i suck at doing my makeup lol',
#   'threat': False,
#   'txt_orig': 'Q: any makeup tips? i suck at doing my makeup lol<br>A: Sure! Like tell me wht u wnna know?! Like wht do you use?!'},
#  {'answer': 'EMMA hahahahah :D I MISSSSSeddd YUHHHHh 222222 <33333',
#   'answer_as_sounds': 'EMMA hahahahah :D I MISSSSSeddd YUHHHHh 222222 <33333',
#   'answer_raw': 'EMMA hahahahah :D I MISSSSSeddd YUHHHHh 222222 <33333',
#   'labels': ['no', 'no', 'no'],
#   'question': "UNKNOWN UNKNOWN İ Myss UNKNOWN IT'Z emma Btw HAHA",
#   'question_as_sounds': "'eIprI2;,I;I2;,I;I2;,I;I2;,I;I2;,I;I2;,Il _:'Ekskl@m,eIS@n_:\n aI m'Is 'V@,Vu:\n Itz 'Em@ b,i:t,i:d'Vb@Lj,u: hA:h'A:",
#   'question_raw': "Apriiiiiiiiiiiill!!! I miss uuuu! It's Emma btw haha",
#   'threat': False,
#   'txt_orig': 'Q: Apriiiiiiiiiiiill!!! I miss uuuu! It&#039;s Emma btw haha<br>A: EMMA hahahahah :D I MISSSSSeddd YUHHHHh 222222 <33333'},
#  {'answer': 'Night 4shuree!!',
#   'answer_as_sounds': 'Night 4shuree!!',
#   'answer_raw': 'Night 4shuree!!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Are _You a_ MORNING or NYTE PERSSON',
#   'question_as_sounds': "A@r- ju: a# m'O@nIN _:_:O@r n'aIt p'3:s@n\n",
#   'question_raw': 'Are you a morning or night person?',
#   'threat': False,
#   'txt_orig': 'Q: Are you a morning or night person?<br>A: Night 4shuree!!'},
#  {'answer': 'alreadi answrd',
#   'answer_as_sounds': 'alreadi answrd',
#   'answer_raw': 'alreadi answrd',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Are _You a_ TRUSTING PERSSON',
#   'question_as_sounds': "A@r- ju: a# tr'VstIN p'3:s@n\n",
#   'question_raw': 'are you a trusting person?',
#   'threat': False,
#   'txt_orig': 'Q: are you a trusting person?<br>A: alreadi answrd'},
#  {'answer': 'Yes veryy trustin person!!! May i help yuh:!',
#   'answer_as_sounds': 'Yes veryy trustin person!!! May i help yuh:!',
#   'answer_raw': 'Yes veryy trustin person!!! May i help yuh:!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Are _You a_ TRUSTING PERSSON',
#   'question_as_sounds': "A@r- ju: a# tr'VstIN p'3:s@n\n",
#   'question_raw': 'are you a trusting person?',
#   'threat': False,
#   'txt_orig': 'Q: are you a trusting person?<br>A: Yes veryy trustin person!!! May i help yuh:!'},
#  {'answer': 'Ahaha!!! Yess of course aint dat rite @TruAce ?!?! Haha He so awesome tho! BCK OFF lol jk',
#   'answer_as_sounds': 'Ahaha!!! Yess of course aint dat rite @TruAce ?!?! Haha He so awesome tho! BCK OFF lol jk',
#   'answer_raw': 'Ahaha!!! Yess of course aint dat rite @TruAce ?!?! Haha He so awesome tho! BCK OFF lol jk',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Are _You ----------------------------------------------------------_And \x81_@ troo AISS BEST frends',
#   'question_as_sounds': "A@r- ju: _:_:and _at_ tr'u: 'eIs b'Est fr'Endz\n",
#   'question_raw': 'Are you and @TruAce best friends?',
#   'threat': False,
#   'txt_orig': 'Q: Are you and @TruAce best friends?<br>A: Ahaha!!! Yess of course aint dat rite @TruAce ?!?! Haha He so awesome tho! BCK OFF lol jk'},
#  {'answer': 'Listener definitely chuz i get cut off alot so i just listen or ignore pplz!',
#   'answer_as_sounds': 'Listener definitely chuz i get cut off alot so i just listen or ignore pplz!',
#   'answer_raw': 'Listener definitely chuz i get cut off alot so i just listen or ignore pplz!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Are _You MORe _Of a_ TALKER or MORe _Of a_ UNKNOWN',
#   'question_as_sounds': "A@r- ju: m'o@r Vv a# t'O:k3r- _:_:O@r m'o@r Vv a# l'Is@n3\n",
#   'question_raw': 'Are you more of a talker or more of a listener?',
#   'threat': False,
#   'txt_orig': 'Q: Are you more of a talker or more of a listener?<br>A: Listener definitely chuz i get cut off alot so i just listen or ignore pplz!'},
#  {'answer': 'Hahaha Yup! Bhut not lookin 4 a man rite atm chuz dey 2much drama!',
#   'answer_as_sounds': 'Hahaha Yup! Bhut not lookin 4 a man rite atm chuz dey 2much drama!',
#   'answer_raw': 'Hahaha Yup! Bhut not lookin 4 a man rite atm chuz dey 2much drama!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Are Yuh Syngal ----------------------------------------------------------_And REDDI 2_ Minggl',
#   'question_as_sounds': "A@r- j'V s'INg@L _:_:and r'Edi; t'u:_! m'INg@L\n",
#   'question_raw': 'Are yuh single and ready 2 mingle?!',
#   'threat': False,
#   'txt_orig': 'Q: Are yuh single and ready 2 mingle?!<br>A: Hahaha Yup! Bhut not lookin 4 a man rite atm chuz dey 2much drama!'},
#  {'answer': ':)',
#   'answer_as_sounds': ':)',
#   'answer_raw': ':)',
#   'labels': ['no', 'no', 'no'],
#   'question': '¡_ASK ME Sumthing UNKNOWN',
#   'question_as_sounds': "'aask m,i:; s'VmTIN _:'Ekskl@m,eIS@n_:\n",
#   'question_raw': 'ask me something!!!',
#   'threat': False,
#   'txt_orig': 'Q: ask me something!!!<br>A: :)'},
#  {'answer': 'Hahahahhaahhaha:D ikrr im a slow american wht more can i say lmfaoo!! hahaha <333 Aww! hahaha',
#   'answer_as_sounds': 'Hahahahhaahhaha:D ikrr im a slow american wht more can i say lmfaoo!! hahaha <333 Aww! hahaha',
#   'answer_raw': 'Hahahahhaahhaha:D ikrr im a slow american wht more can i say lmfaoo!! hahaha <333 Aww! hahaha',
#   'labels': ['no', 'no', 'no'],
#   'question': 'Bahah ÃÂ aha TOOK _You LONGER Enuff UNKNOWN jeeze Gurle Hahah Knoah Ites TOTALLY OKAY ▪_i _Just wonted _to Pley Guese who ▪_i Am HAHAHA dot_xxx_domain dot_xxx_domain ▪_i UNKNOWN Lovee _You tú ----------------------------------------------------------_3',
#   'question_as_sounds': "b'ah@ 'A: a#h'A:\n t'Uk ju: l'0Ng3r- I2n'Vf p'i:\n dZ'i:z g'3:l h'ah@\n n'oU Its t'oUt#@Lli; oUk'eI\n 'aI dZ'Vst w'0nt#I2d tU pl'eI g'Es _:_:h,u: 'aI am hah'A:h@ d'0t d'0t 'aI f'VkINg l'Vv ju: t'u:\n _:_:Tr'i:_!",
#   'question_raw': 'BAHAHAhAHA....took you longer enough;p......GEES GIRL hahah...no its totally okay:) i just wanted to play guess who i am hahaha..i fuckinggg love you too;) <3',
#   'threat': False,
#   'txt_orig': 'Q: BAHAHAhAHA....took you longer enough;p......GEES GIRL hahah...no its totally okay:) i just wanted to play guess who i am hahaha..i fuckinggg love you too;) <3<br>A: Hahahahhaahhaha:D ikrr im a slow american wht more can i say lmfaoo!! hahaha <333 Aww! hahaha'},
#  {'answer': 'lmaoo!!!!',
#   'answer_as_sounds': 'lmaoo!!!!',
#   'answer_raw': 'lmaoo!!!!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'UNKNOWN p_≤',
#   'question_as_sounds': "b,aha#h,ahA:h'A:h@ p'i:;",
#   'question_raw': 'bahahahahhaha ;p',
#   'threat': False,
#   'txt_orig': 'Q: bahahahahhaha ;p<br>A: lmaoo!!!!'},
#  {'answer': 'Hahah(: Thanks!',
#   'answer_as_sounds': 'Hahah(: Thanks!',
#   'answer_raw': 'Hahah(: Thanks!',
#   'labels': ['no', 'no', 'yes'],
#   'question': 'Biche ♥_U THEE Bombe Lieck Tyk Tyk',
#   'question_as_sounds': "b'ItS j'u: D,i:; b'0m l'aIk t'Ik t'Ik\n",
#   'question_raw': 'Bitch u thee bomb like Tick TICK!',
#   'threat': False,
#   'txt_orig': 'Q: Bitch u thee bomb like Tick TICK!<br>A: Hahah(: Thanks!'},
#  {'answer': 'Hahaha... I dont sing!! LOL! so srry! Im horrible. btw I dedicate "SMILE" 2 yuh! Its playing!!',
#   'answer_as_sounds': 'Hahaha... I dont sing!! LOL! so srry! Im horrible. btw I dedicate "SMILE" 2 yuh! Its playing!!',
#   'answer_raw': 'Hahaha... I dont sing!! LOL! so srry! Im horrible. btw I dedicate "SMILE" 2 yuh! Its playing!!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Can _You plese Syng a_ covere _Of ANY Justyn BIEBER SONG Kohlen Deee',
#   'question_as_sounds': "kan ju: pl'i:z s'IN a# k'Vv3r- Vv ,Eni; dZ'VstIn b'i:b3r- s'ON\n k'oUl@n d'i:;",
#   'question_raw': 'can you please sing a cover of any justin bieber song? :D',
#   'threat': False,
#   'txt_orig': 'Q: can you please sing a cover of any justin bieber song? :D<br>A: Hahaha... I dont sing!! LOL! so srry! Im horrible. btw I dedicate &quot;SMILE&quot; 2 yuh! Its playing!!'},
#  {'answer': 'Dogs! Im allergic 2 cats=',
#   'answer_as_sounds': 'Dogs! Im allergic 2 cats=',
#   'answer_raw': 'Dogs! Im allergic 2 cats=',
#   'labels': ['no', 'no', 'no'],
#   'question': 'katz or Dogues',
#   'question_as_sounds': "k'ats _:_:O@r d'0gz\n",
#   'question_raw': 'Cats or Dogs?',
#   'threat': False,
#   'txt_orig': 'Q: Cats or Dogs?<br>A: Dogs! Im allergic 2 cats='},
#  {'answer': 'Chocolate! Bahah!',
#   'answer_as_sounds': 'Chocolate! Bahah!',
#   'answer_raw': 'Chocolate! Bahah!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'CHOCOLATE or VANILLA',
#   'question_as_sounds': "tS'0kl@t _:_:O@r van'Il@\n",
#   'question_raw': 'Chocolate or Vanilla?',
#   'threat': False,
#   'txt_orig': 'Q: Chocolate or Vanilla?<br>A: Chocolate! Bahah!'},
#  {'answer': 'Ahhh!!;) wow 5yrs! man  its a gorgeous language! I love it!! this is my first year learnin it! haha NEWBIE!',
#   'answer_as_sounds': 'Ahhh!!;) wow 5yrs! man  its a gorgeous language! I love it!! this is my first year learnin it! haha NEWBIE!',
#   'answer_raw': 'Ahhh!!;) wow 5yrs! man  its a gorgeous language! I love it!! this is my first year learnin it! haha NEWBIE!',
#   'labels': ['no', 'no', 'no'],
#   'question': "DEFINITELY troo Kohlen Deee I'v BEEN Learnin it' _for ___________________________________________________________5 years' kuhs I'v UNKNOWN ORIGINS HAHA UNKNOWN",
#   'question_as_sounds': "d'EfI2n@tli; tr'u:\n k'oUl@n d'i:; aIv b,In l'3:nIn It fO@r f'aIv_! j'i@3z k'Vz aIv fr'EnS 'O:rI2dZ,Inz hA:h'A: ,Eks,Eks'Eks\n",
#   'question_raw': "definitely true! :D i've been learnin it for 5 years cuz i've frensh origins haha ;)",
#   'threat': False,
#   'txt_orig': 'Q: definitely true! :D i&#039;ve been learnin it for 5 years cuz i&#039;ve frensh origins haha ;)<br>A: Ahhh!!;) wow 5yrs! man  its a gorgeous language! I love it!! this is my first year learnin it! haha NEWBIE!'},
#  {'answer': 'Well sortaa! I just got 2 wtch thee Charice part! Shes awesome <3 hbu?!',
#   'answer_as_sounds': 'Well sortaa! I just got 2 wtch thee Charice part! Shes awesome <3 hbu?!',
#   'answer_raw': 'Well sortaa! I just got 2 wtch thee Charice part! Shes awesome <3 hbu?!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'dydd ♥_U Woche BIEBER _On Opra',
#   'question_as_sounds': "d'Id j'u: w'0tS b'i:b3r- ,0n '0pr@\n",
#   'question_raw': 'Did u watch bieber on oprah?',
#   'threat': False,
#   'txt_orig': 'Q: Did u watch bieber on oprah?<br>A: Well sortaa! I just got 2 wtch thee Charice part! Shes awesome <3 hbu?!'},
#  {'answer': 'Yes of course i do... Its called Eternity with God in heaven!<3',
#   'answer_as_sounds': 'Yes of course i do... Its called Eternity with God in heaven!<3',
#   'answer_raw': 'Yes of course i do... Its called Eternity with God in heaven!<3',
#   'labels': ['no', 'no', 'no'],
#   'question': "dû _You Beleive IN' LYFE aftter DEATH",
#   'question_as_sounds': "d'u: ju: bI2l'i:v In l'aIf 'aaft3r- d'ET\n",
#   'question_raw': 'Do you believe in life after death?',
#   'threat': False,
#   'txt_orig': 'Q: Do you believe in life after death?<br>A: Yes of course i do... Its called Eternity with God in heaven!<3'},
#  {'answer': 'Yes  bhut I think luck is blessing from God actually! in my opinioN!',
#   'answer_as_sounds': 'Yes  bhut I think luck is blessing from God actually! in my opinioN!',
#   'answer_raw': 'Yes  bhut I think luck is blessing from God actually! in my opinioN!',
#   'labels': ['no', 'no', 'no'],
#   'question': "dû _You Beleive IN' LLUK",
#   'question_as_sounds': "d'u: ju: bI2l'i:v In l'Vk\n",
#   'question_raw': 'Do you believe in luck?',
#   'threat': False,
#   'txt_orig': 'Q: Do you believe in luck?<br>A: Yes  bhut I think luck is blessing from God actually! in my opinioN!'},
#  {'answer': 'If God created them then hellz yes!',
#   'answer_as_sounds': 'If God created them then hellz yes!',
#   'answer_raw': 'If God created them then hellz yes!',
#   'labels': ['no', 'no', 'no'],
#   'question': "dû _You Beleive There's inteligent LYFE _On othere PLANETS",
#   'question_as_sounds': "d'u: ju: bI2l'i:v De@z Int'ElIdZ@nt l'aIf ,0n 'VD3r- pl'anEts\n",
#   'question_raw': "Do you believe there's intelligent life on other planets?",
#   'threat': False,
#   'txt_orig': 'Q: Do you believe there&#039;s intelligent life on other planets?<br>A: If God created them then hellz yes!'},
#  {'answer': 'Hahaha Bitch i bring it lmao! Kinda i think lmao! I hve some black in me so yes haha',
#   'answer_as_sounds': 'Hahaha Bitch i bring it lmao! Kinda i think lmao! I hve some black in me so yes haha',
#   'answer_raw': 'Hahaha Bitch i bring it lmao! Kinda i think lmao! I hve some black in me so yes haha',
#   'labels': ['no', 'no', 'no'],
#   'question': 'dû _You CONSIDER YOURSELF a_ GOODE UNKNOWN',
#   'question_as_sounds': "d'u: ju: k0ns'Id3r- jo@s'Elf a# g'Ud d'aans3\n",
#   'question_raw': 'Do you consider yourself a good dancer?',
#   'threat': False,
#   'txt_orig': 'Q: Do you consider yourself a good dancer?<br>A: Hahaha Bitch i bring it lmao! Kinda i think lmao! I hve some black in me so yes haha'},
#  {'answer': 'Nope ;/ Bhut Not Having a BF doesnt mean The WORLD ends;] I guess im waiting 4 the 1  ya kno? Hbu mamas?!',
#   'answer_as_sounds': 'Nope ;/ Bhut Not Having a BF doesnt mean The WORLD ends;] I guess im waiting 4 the 1  ya kno? Hbu mamas?!',
#   'answer_raw': 'Nope ;/ Bhut Not Having a BF doesnt mean The WORLD ends;] I guess im waiting 4 the 1  ya kno? Hbu mamas?!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'dû _You _Have a_ Bf',
#   'question_as_sounds': "d'u: ju: hav a# b,i:;'Ef\n",
#   'question_raw': 'do you have a bf??',
#   'threat': False,
#   'txt_orig': 'Q: do you have a bf??<br>A: Nope ;/ Bhut Not Having a BF doesnt mean The WORLD ends;] I guess im waiting 4 the 1  ya kno? Hbu mamas?!'},
#  {'answer': 'I have 2 actually! Justin Bieber (ofcourse) andand Scipio Mondai!',
#   'answer_as_sounds': 'I have 2 actually! Justin Bieber (ofcourse) andand Scipio Mondai!',
#   'answer_raw': 'I have 2 actually! Justin Bieber (ofcourse) andand Scipio Mondai!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'dû _You _Have ANY _Favorite _You Toob UNKNOWN',
#   'question_as_sounds': "d'u: ju: hav ,Eni; f'eIv@-rI2t ju: t'u:b st'A@\n",
#   'question_raw': 'Do you have any favorite YouTube star?',
#   'threat': False,
#   'txt_orig': 'Q: Do you have any favorite YouTube star?<br>A: I have 2 actually! Justin Bieber (ofcourse) &amp;&amp; Scipio Mondai!'},
#  {'answer': 'Actually i do!!! Just my whole experience with this fake a$$ friend!!</3',
#   'answer_as_sounds': 'Actually i do!!! Just my whole experience with this fake a$$ friend!!</3',
#   'answer_raw': 'Actually i do!!! Just my whole experience with this fake a$$ friend!!</3',
#   'labels': ['no', 'no', 'no'],
#   'question': "dû _You _Have ANY MEMORIES You'd Lieck _to Forgette",
#   'question_as_sounds': "d'u: ju: hav ,Eni; m'Em3rIz ju:d l'aIk tU f3g'Et\n",
#   'question_raw': "do you have any memories you'd like to forget?",
#   'threat': False,
#   'txt_orig': 'Q: do you have any memories you&#039;d like to forget?<br>A: Actually i do!!! Just my whole experience with this fake a$$ friend!!</3'},
#  {'answer': 'Yuppers! Nose and Cartilage piercings(;',
#   'answer_as_sounds': 'Yuppers! Nose and Cartilage piercings(;',
#   'answer_raw': 'Yuppers! Nose and Cartilage piercings(;',
#   'labels': ['no', 'no', 'no'],
#   'question': 'dû _You _Have ANY Piercings',
#   'question_as_sounds': "d'u: ju: hav ,Eni; p'i@3sINz\n",
#   'question_raw': 'Do you have any piercings?',
#   'threat': False,
#   'txt_orig': 'Q: Do you have any piercings?<br>A: Yuppers! Nose and Cartilage piercings(;'},
#  {'answer': 'Hahaha. Strange!:S',
#   'answer_as_sounds': 'Hahaha. Strange!:S',
#   'answer_raw': 'Hahaha. Strange!:S',
#   'labels': ['no', 'no', 'no'],
#   'question': "dû _You _Have ANY SCARs _On You're UNKNOWN _If SO how'd _You _Get THEM",
#   'question_as_sounds': "d'u: ju: hav ,Eni; sk'A@z ,0n jU@r- b'0di\n If s,oU h,aUd ju: gEt D,Em\n",
#   'question_raw': "Do you have any scars on your body?  If so  how'd you get them?",
#   'threat': False,
#   'txt_orig': 'Q: Do you have any scars on your body?  If so  how&#039;d you get them?<br>A: Hahaha. Strange!:S'},
#  {'answer': 'yes i love ATL!! great place 2 live  wish i lived there! ;D',
#   'answer_as_sounds': 'yes i love ATL!! great place 2 live  wish i lived there! ;D',
#   'answer_raw': 'yes i love ATL!! great place 2 live  wish i lived there! ;D',
#   'labels': ['no', 'no', 'no'],
#   'question': 'dû _You Lieck _Atlanta Gha UNKNOWN',
#   'question_as_sounds': "d'u: ju: l'aIk a#tl'ant#@ g'A: ,Eks,Eks'Eks\n",
#   'question_raw': 'do you like atlanta  GA ?',
#   'threat': False,
#   'txt_orig': 'Q: do you like atlanta  GA ?<br>A: yes i love ATL!! great place 2 live  wish i lived there! ;D'},
#  {'answer': "Omg NO WAY!!! 10 is actually small!!! Don't change thee way you look 4 ANYONE!!! bhut yourslf. Kay?!",
#   'answer_as_sounds': "Omg NO WAY!!! 10 is actually small!!! Don't change thee way you look 4 ANYONE!!! bhut yourslf. Kay?!",
#   'answer_raw': "Omg NO WAY!!! 10 is actually small!!! Don't change thee way you look 4 ANYONE!!! bhut yourslf. Kay?!",
#   'labels': ['no', 'no', 'no'],
#   'question': "dû _You THINC _that a_ Cise UNKNOWN _is_ fatt I'm TRYING _to BE a_ Cise ___________________________________________________________5 BY' __The ende _Of __The UNKNOWN",
#   'question_as_sounds': "d'u: ju: T'INk Dat a# s'aIz t'En_! Iz f'at\n aIm tr'aIIN tU bi:; a# s'aIz f'aIv_! baI DI2; 'End Vv DI2; j'i@3\n",
#   'question_raw': "do you think that a size 10 is fat? i'm trying to be a size 5 by the end of the year.",
#   'threat': False,
#   'txt_orig': "Q: do you think that a size 10 is fat? i&#039;m trying to be a size 5 by the end of the year.<br>A: Omg NO WAY!!! 10 is actually small!!! Don't change thee way you look 4 ANYONE!!! bhut yourslf. Kay?!"},
#  {'answer': 'Fuck yes i think i am! haha',
#   'answer_as_sounds': 'Fuck yes i think i am! haha',
#   'answer_raw': 'Fuck yes i think i am! haha',
#   'labels': ['no', 'no', 'no'],
#   'question': "dû _You THINC You're a_ GOODE frend",
#   'question_as_sounds': "d'u: ju: T'INk jU@r- a# g'Ud fr'End\n",
#   'question_raw': "do you think you're a good friend?",
#   'threat': False,
#   'txt_orig': 'Q: do you think you&#039;re a good friend?<br>A: Fuck yes i think i am! haha'},
#  {'answer': 'Awww man you just reminded me! I wtch it sometimes bhut i love Big Mike! Pplz are really wrong bout letting Katie go!! Argh . .',
#   'answer_as_sounds': 'Awww man you just reminded me! I wtch it sometimes bhut i love Big Mike! Pplz are really wrong bout letting Katie go!! Argh . .',
#   'answer_raw': 'Awww man you just reminded me! I wtch it sometimes bhut i love Big Mike! Pplz are really wrong bout letting Katie go!! Argh . .',
#   'labels': ['no', 'no', 'no'],
#   'question': 'dû _You Woche Americn Idole _If SO who _Are _You VOTING _for _This SEASON',
#   'question_as_sounds': "d'u: ju: w'0tS a#m'ErIk@n 'aId@L\n If s,oU _:_:h,u: A@r- ju: v'oUt#IN fO@r DIs s'i:z@n\n",
#   'question_raw': 'do you watch american idol? if so  who are you voting for this season?',
#   'threat': False,
#   'txt_orig': 'Q: do you watch american idol? if so  who are you voting for this season?<br>A: Awww man you just reminded me! I wtch it sometimes bhut i love Big Mike! Pplz are really wrong bout letting Katie go!! Argh . .'},
#  {'answer': 'Hell yes! Lots of them and thats including yuh!<3',
#   'answer_as_sounds': 'Hell yes! Lots of them and thats including yuh!<3',
#   'answer_raw': 'Hell yes! Lots of them and thats including yuh!<3',
#   'labels': ['no', 'no', 'no'],
#   'question': 'dû Yuh _Have ANY Stalkers',
#   'question_as_sounds': "d'u: j'V hav ,Eni; st'O:k3z\n",
#   'question_raw': 'Do yuh have any stalkers?',
#   'threat': False,
#   'txt_orig': 'Q: Do yuh have any stalkers?<br>A: Hell yes! Lots of them and thats including yuh!<3'},
#  {'answer': ':D thank you gurl/boy ? I really appreciate it!<33',
#   'answer_as_sounds': ':D thank you gurl/boy ? I really appreciate it!<33',
#   'answer_raw': ':D thank you gurl/boy ? I really appreciate it!<33',
#   'labels': ['no', 'no', 'no'],
#   'question': 'Deaunte Lissen _to __The Hayters _You _Are UNKNOWN',
#   'question_as_sounds': "d'oUnt l'Is@n tU DI2; h'eIt#3z ju: A@r- pr'It#i\n",
#   'question_raw': "don't listen to the haters  you are pretty!",
#   'threat': False,
#   'txt_orig': 'Q: don&#039;t listen to the haters  you are pretty!<br>A: :D thank you gurl/boy ? I really appreciate it!<33'},
#  {'answer': 'ATM Rue 21;D Or Forever21 <3',
#   'answer_as_sounds': 'ATM Rue 21;D Or Forever21 <3',
#   'answer_raw': 'ATM Rue 21;D Or Forever21 <3',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Favorite UNKNOWN',
#   'question_as_sounds': "f'eIv@-rI2t st'o@\n",
#   'question_raw': 'Favorite store?',
#   'threat': False,
#   'txt_orig': 'Q: Favorite store?<br>A: ATM Rue 21;D Or Forever21 <3'},
#  {'answer': 'UM excuse yuh? HE IS NOT!! Ur a fuckin idiot! Kay? good',
#   'answer_as_sounds': 'UM excuse yuh? HE IS NOT!! Ur a fuckin idiot! Kay? good',
#   'answer_raw': 'UM excuse yuh? HE IS NOT!! Ur a fuckin idiot! Kay? good',
#   'labels': ['yes', 'yes', 'yes'],
#   'question': "phuck Justyn UNKNOWN He's a_ FUCKING Fag",
#   'question_as_sounds': "f'Vk dZ'VstIn b'i:b3\n hi:z a# f'VkIN f'ag",
#   'question_raw': "Fuck Justin bieber. He's a fucking fag",
#   'threat': True,
#   'txt_orig': 'Q: Fuck Justin bieber. He&#039;s a fucking fag<br>A: UM excuse yuh? HE IS NOT!! Ur a fuckin idiot! Kay? good'},
#  {'answer': 'Meowl?;D If thts a word haha<3',
#   'answer_as_sounds': 'Meowl?;D If thts a word haha<3',
#   'answer_raw': 'Meowl?;D If thts a word haha<3',
#   'labels': ['no', 'no', 'no'],
#   'question': 'GROWL',
#   'question_as_sounds': "gr'aUl\n",
#   'question_raw': 'growl;]',
#   'threat': False,
#   'txt_orig': 'Q: growl;]<br>A: Meowl?;D If thts a word haha<3'},
#  {'answer': 'Idk hoe get cha own cup of blackberry with a hint of lemon ice tea. Dayumm! hahah JK Brooke?',
#   'answer_as_sounds': 'Idk hoe get cha own cup of blackberry with a hint of lemon ice tea. Dayumm! hahah JK Brooke?',
#   'answer_raw': 'Idk hoe get cha own cup of blackberry with a hint of lemon ice tea. Dayumm! hahah JK Brooke?',
#   'labels': ['no', 'no', 'no'],
#   'question': 'Guese who UNKNOWN',
#   'question_as_sounds': "g'Es _:_:h,u: ,Eks,Eks'Eks\n",
#   'question_raw': 'guesss who ;)',
#   'threat': False,
#   'txt_orig': 'Q: guesss who ;)<br>A: Idk hoe get cha own cup of blackberry with a hint of lemon ice tea. Dayumm! hahah JK Brooke?'},
#  {'answer': 'Off courrseeee dudee hahahahaha!!!! Awhhh lol! i think i love it 2 chuz im in it lol!!!! jk! i love yuh!!',
#   'answer_as_sounds': 'Off courrseeee dudee hahahahaha!!!! Awhhh lol! i think i love it 2 chuz im in it lol!!!! jk! i love yuh!!',
#   'answer_raw': 'Off courrseeee dudee hahahahaha!!!! Awhhh lol! i think i love it 2 chuz im in it lol!!!! jk! i love yuh!!',
#   'labels': ['no', 'no', 'no'],
#   'question': "HAAH _You UNKNOWN UNKNOWN Kohlen DOCTER Ites UNKNOWN ÃÂ UNKNOWN _This UNKNOWN UNKNOWN Maib Becuase UNKNOWN IN' it' BABE ----------------------------------------------------------_3",
#   'question_as_sounds': "h'A: ju: g'EsEd r'Ight k'oUl@n d'0kt3r- Its m'e@rIjji\n 'A: 'aIl@v,i:; DIs p'IktS3 _:'Ekskl@m,eIS@n_:\n m'eIb bI2kw'as j'aUhr@ In It b'eIb _:_:Tr'i:_!",
#   'question_raw': '-Haa you guessedd righhtttt:Dr its Maryyyy(: ahhh ilovee this picture!!!!!!!!!! mayb becuase youhr in it babe<3',
#   'threat': False,
#   'txt_orig': 'Q: -Haa you guessedd righhtttt:Dr its Maryyyy(: ahhh ilovee this picture!!!!!!!!!! mayb becuase youhr in it babe<3<br>A: Off courrseeee dudee hahahahaha!!!! Awhhh lol! i think i love it 2 chuz im in it lol!!!! jk! i love yuh!!'},
#  {'answer': 'lmfao! haha! Nahh its my badd;)',
#   'answer_as_sounds': 'lmfao! haha! Nahh its my badd;)',
#   'answer_raw': 'lmfao! haha! Nahh its my badd;)',
#   'labels': ['no', 'no', 'no'],
#   'question': 'HAAA Ites Aule UNKNOWN Sorrie UNKNOWN __The UNKNOWN Thinq iwas Madde Loll',
#   'question_as_sounds': "h'a:@ Its 'O:l kw@d s'O:ri; a#b'aUht DI2; _:_:h'oU T'Ink 'Iw@z m'ad l'0l",
#   'question_raw': 'haaa its all qud  sorry abouht the "hoe" thinq  iwas mad lol',
#   'threat': False,
#   'txt_orig': 'Q: haaa its all qud  sorry abouht the &quot;hoe&quot; thinq  iwas mad lol<br>A: lmfao! haha! Nahh its my badd;)'},
#  {'answer': 'Pfftt!! nahhh i hve never been outta this country!! Argh! hve yuh?! haha',
#   'answer_as_sounds': 'Pfftt!! nahhh i hve never been outta this country!! Argh! hve yuh?! haha',
#   'answer_raw': 'Pfftt!! nahhh i hve never been outta this country!! Argh! hve yuh?! haha',
#   'labels': ['no', 'no', 'no'],
#   'question': 'HAHA UNKNOWN UNKNOWN _Have ♥_U EVER BEEN _to france',
#   'question_as_sounds': "hA:h'A: ,Eks,Eks'Eks\n _:_:s'oU\n hav j'u: 'Ev3r- b,In tU fr'aans\n",
#   'question_raw': 'haha ;)so.. have u ever been to france?',
#   'threat': False,
#   'txt_orig': 'Q: haha ;)so.. have u ever been to france?<br>A: Pfftt!! nahhh i hve never been outta this country!! Argh! hve yuh?! haha'},
#  {'answer': 'Lmao!! kk lemme get my ass off this toliet seat then ill check!! Mwahah!! jk',
#   'answer_as_sounds': 'Lmao!! kk lemme get my ass off this toliet seat then ill check!! Mwahah!! jk',
#   'answer_raw': 'Lmao!! kk lemme get my ass off this toliet seat then ill check!! Mwahah!! jk',
#   'labels': ['no', 'no', 'no'],
#   'question': "HAHA CHEQ Insyde erh CLOSET ♥_U MINED FINED Out who it' _is_",
#   'question_as_sounds': "hA:h'A: tS'Ek Ins'aId '3:r- kl'0zI2t j'u: m'aInd f'aInd 'aUt _:_:h,u: It Iz\n",
#   'question_raw': 'haha check inside ur closet u mind find out who it is(;',
#   'threat': False,
#   'txt_orig': 'Q: haha check inside ur closet u mind find out who it is(;<br>A: Lmao!! kk lemme get my ass off this toliet seat then ill check!! Mwahah!! jk'},
#  {'answer': 'OMG!!!!! tell me!!!! ughh grrr rawrr bianca? LMAO! idkk TELL ME!',
#   'answer_as_sounds': 'OMG!!!!! tell me!!!! ughh grrr rawrr bianca? LMAO! idkk TELL ME!',
#   'answer_raw': 'OMG!!!!! tell me!!!! ughh grrr rawrr bianca? LMAO! idkk TELL ME!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'HAHA NOPE IMb NOTT UNKNOWN UNKNOWN ▪_i TAWK TO _You ALLOT _On UNKNOWN ----------------------------------------------------------_3',
#   'question_as_sounds': "hA:h'A: n'oUp 'Im n'0t t'akwIS@ 'i:D3\n 'aI t'O:k tu: ju: a#l'0t ,0n tw'It#3\n _:_:Tr'i:_!",
#   'question_raw': 'HAHA NOPE IM NOT TAQUISHA EITHER....i TALK TO YOU ALOT ON TWITTER;) <3',
#   'threat': False,
#   'txt_orig': 'Q: HAHA NOPE IM NOT TAQUISHA EITHER....i TALK TO YOU ALOT ON TWITTER;) <3<br>A: OMG!!!!! tell me!!!! ughh grrr rawrr bianca? LMAO! idkk TELL ME!'},
#  {'answer': 'Mary?! lol hahahaha',
#   'answer_as_sounds': 'Mary?! lol hahahaha',
#   'answer_raw': 'Mary?! lol hahahaha',
#   'labels': ['no', 'no', 'no'],
#   'question': 'Hahah Guese Houx ----------------------------------------------------------_3',
#   'question_as_sounds': "h'ah@ g'Es h'u:\n _:_:Tr'i:_!",
#   'question_raw': 'HAHAH GUESS WHO!? <3',
#   'threat': False,
#   'txt_orig': 'Q: HAHAH GUESS WHO!? <3<br>A: Mary?! lol hahahaha'},
#  {'answer': 'Mwahaha!!! Sweet thang! i love it!!',
#   'answer_as_sounds': 'Mwahaha!!! Sweet thang! i love it!!',
#   'answer_raw': 'Mwahaha!!! Sweet thang! i love it!!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'Hahah okie UNKNOWN UNKNOWN dot_xxx_domain Sweete THANG',
#   'question_as_sounds': "h'ah@ 'oUki; d'oUki _:'Ekskl@m,eIS@n_:d,0t d'0t sw'i:t T'aN\n",
#   'question_raw': 'hahah okey dokey!..sweet thang(;',
#   'threat': False,
#   'txt_orig': 'Q: hahah okey dokey!..sweet thang(;<br>A: Mwahaha!!! Sweet thang! i love it!!'},
#  {'answer': 'and its also funny how u stalked my whole twitter! Nice goin! BITCH!',
#   'answer_as_sounds': 'and its also funny how u stalked my whole twitter! Nice goin! BITCH!',
#   'answer_raw': 'and its also funny how u stalked my whole twitter! Nice goin! BITCH!',
#   'labels': ['no', 'yes', 'yes'],
#   'question': "Hahah Phunny HOW' ♥_U DEFEND _that Beiber kidd",
#   'question_as_sounds': "h'ah@\n f'Vni; h,aU j'u: dI2f'End Dat b'eIb3r- k'Id\n",
#   'question_raw': 'Hahah. Funny how u defend that beiber kid.',
#   'threat': True,
#   'txt_orig': 'Q: Hahah. Funny how u defend that beiber kid.<br>A: &amp; its also funny how u stalked my whole twitter! Nice goin! BITCH!'},
#  {'answer': 'Uhhhhh!!!! OMG! Taquisha? LOL!',
#   'answer_as_sounds': 'Uhhhhh!!!! OMG! Taquisha? LOL!',
#   'answer_raw': 'Uhhhhh!!!! OMG! Taquisha? LOL!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'HAHAHA NOPE UNKNOWN',
#   'question_as_sounds': "hah'A:h@ n'oUp\n ,Eks,Eks'Eks\n",
#   'question_raw': 'HAHAHA NOPE! ...',
#   'threat': False,
#   'txt_orig': 'Q: HAHAHA NOPE! ...<br>A: Uhhhhh!!!! OMG! Taquisha? LOL!'},
#  {'answer': 'Hahaha.. Yup!(: Its my job',
#   'answer_as_sounds': 'Hahaha.. Yup!(: Its my job',
#   'answer_raw': 'Hahaha.. Yup!(: Its my job',
#   'labels': ['no', 'yes', 'no'],
#   'question': '_Have ♥_U EVER LICKED THEE UNKNOWN',
#   'question_as_sounds': "hav j'u: 'Ev3r- l'Ikt D,i:; fl'o@\n",
#   'question_raw': 'Have u ever licked thee floor?',
#   'threat': False,
#   'txt_orig': 'Q: Have u ever licked thee floor?<br>A: Hahaha.. Yup!(: Its my job'},
#  {'answer': 'Nope:[ I wish  bhut hey i might someday rite haha..Hbu?!',
#   'answer_as_sounds': 'Nope:[ I wish  bhut hey i might someday rite haha..Hbu?!',
#   'answer_raw': 'Nope:[ I wish  bhut hey i might someday rite haha..Hbu?!',
#   'labels': ['no', 'no', 'no'],
#   'question': "_Have ♥_U CEIN Justyn BIEBER IN' PERSSON UNKNOWN",
#   'question_as_sounds': "hav j'u: s'i:n dZ'VstIn b'i:b3r- In p'3:s@n\n ,Eks,Eks'Eks\n",
#   'question_raw': 'have u seen JUSTIN BIEBER in person? (:',
#   'threat': False,
#   'txt_orig': 'Q: have u seen JUSTIN BIEBER in person? (:<br>A: Nope:[ I wish  bhut hey i might someday rite haha..Hbu?!'},
#  {'answer': 'Haha nahh ive just fractured some thumbs bhut itz all good lol',
#   'answer_as_sounds': 'Haha nahh ive just fractured some thumbs bhut itz all good lol',
#   'answer_raw': 'Haha nahh ive just fractured some thumbs bhut itz all good lol',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Have _You BROKEN ANY Bohns _If SO howe',
#   'question_as_sounds': "hav ju: br'oUk@n ,Eni; b'oUnz\n If s,oU h'aU\n",
#   'question_raw': 'Have you broken any bones?  If so  how?',
#   'threat': False,
#   'txt_orig': 'Q: Have you broken any bones?  If so  how?<br>A: Haha nahh ive just fractured some thumbs bhut itz all good lol'},
#  {'answer': 'Hahah OHKAY?!',
#   'answer_as_sounds': 'Hahah OHKAY?!',
#   'answer_raw': 'Hahah OHKAY?!',
#   'labels': ['no', 'no', 'no'],
#   'question': "_Have _You EVER BEEN _On UNKNOWN dot_xxx_domain Komme GO' _There ----------------------------------------------------------_And telle Sumthing _to __The _World Kohlen Deee",
#   'question_as_sounds': "hav ju: 'Ev3r- b,In ,0n 'aIt#@LI2;,u:Tat d'0t k'0m\n g,oU De@r _:_:and t'El s'VmTIN tU DI2; w'3:ld k'oUl@n d'i:;",
#   'question_raw': 'have you ever been on itellyouthat.com? go there and tell something to the world :D',
#   'threat': False,
#   'txt_orig': 'Q: have you ever been on itellyouthat.com? go there and tell something to the world :D<br>A: Hahah OHKAY?!'},
#  {'answer': 'Yup yup!!:P',
#   'answer_as_sounds': 'Yup yup!!:P',
#   'answer_raw': 'Yup yup!!:P',
#   'labels': ['no', 'no', 'no'],
#   'question': "_Have _You EVER HAD You're HARTE BROKEN",
#   'question_as_sounds': "hav ju: 'Ev3r- ha#d jU@r- h'A@t br'oUk@n\n",
#   'question_raw': 'have you ever had your heart broken?',
#   'threat': False,
#   'txt_orig': 'Q: have you ever had your heart broken?<br>A: Yup yup!!:P'},
#  {'answer': 'haha!! it is haha lol!! man i hvnt even gotten 2 dat part yet! FML hah',
#   'answer_as_sounds': 'haha!! it is haha lol!! man i hvnt even gotten 2 dat part yet! FML hah',
#   'answer_raw': 'haha!! it is haha lol!! man i hvnt even gotten 2 dat part yet! FML hah',
#   'labels': ['no', 'no', 'no'],
#   'question': "Hehe yup IT'Z AWSOME but __The Pronunciation _is_ INCREDIBLY UNKNOWN Kohlen Deee",
#   'question_as_sounds': "hi:h'i:; j'Vp Itz 'O:sVm _:_:b,Vt DI2; pr@n,VnsI2;'eIS@n Iz Inkr'EdIbli; h'a:A@d k'oUl@n d'i:;",
#   'question_raw': "hehe yup  it's awesome  but the pronunciation is incredibly haaard :D",
#   'threat': False,
#   'txt_orig': 'Q: hehe yup  it&#039;s awesome  but the pronunciation is incredibly haaard :D<br>A: haha!! it is haha lol!! man i hvnt even gotten 2 dat part yet! FML hah'},
#  {'answer': 'Ohh heyy bitchh!!! its goin good..:D thx 4 askin',
#   'answer_as_sounds': 'Ohh heyy bitchh!!! its goin good..:D thx 4 askin',
#   'answer_raw': 'Ohh heyy bitchh!!! its goin good..:D thx 4 askin',
#   'labels': ['yes', 'no', 'no'],
#   'question': "HELLO Biche HOWS erh Daie UNKNOWN GOODE İ HOPe UNKNOWN IT'Z beutiful ----------------------------------------------------------_And UNKNOWN",
#   'question_as_sounds': "h@l'oU b'ItS\n h,aUz '3:r- d'eI g'oUI2N\n g'Ud aI h'oUp ,Eks,Eks'Eks\n Itz bj'u:t#If@L _:_:and s'Vni\n",
#   'question_raw': "Hello bitch! How's ur day going? Good I hope :) it's beautiful and sunny!",
#   'threat': False,
#   'txt_orig': 'Q: Hello bitch! How&#039;s ur day going? Good I hope :) it&#039;s beautiful and sunny!<br>A: Ohh heyy bitchh!!! its goin good..:D thx 4 askin'},
#  {'answer': 'Nicee!',
#   'answer_as_sounds': 'Nicee!',
#   'answer_raw': 'Nicee!',
#   'labels': ['no', 'no', 'no'],
#   'question': "HELLO MY' frend _is_ _Also NAMED Aprille",
#   'question_as_sounds': "h@l'oU\n maI fr'End Iz '0lsoU n'eImd 'eIprIl\n",
#   'question_raw': 'Hello. My friend is also named April.',
#   'threat': False,
#   'txt_orig': 'Q: Hello. My friend is also named April.<br>A: Nicee!'},
#  {'answer': 'Hey  hows yah momma?!',
#   'answer_as_sounds': 'Hey  hows yah momma?!',
#   'answer_raw': 'Hey  hows yah momma?!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'HELLO',
#   'question_as_sounds': "h@l'oU\n",
#   'question_raw': 'Hello?',
#   'threat': False,
#   'txt_orig': 'Q: Hello?<br>A: Hey  hows yah momma?!'},
#  {'answer': 'ahahaha!!!(: It wuzz funn!(: lmao<3',
#   'answer_as_sounds': 'ahahaha!!!(: It wuzz funn!(: lmao<3',
#   'answer_raw': 'ahahaha!!!(: It wuzz funn!(: lmao<3',
#   'labels': ['no', 'no', 'no'],
#   'question': "HELLS Yeahhhh _Of corss I'm UNKNOWN ▪_i WANNA bhee withh _You KWES Lieck dû ----------------------------------------------------------_3",
#   'question_as_sounds': "h'Elz j'Eh\n Vv k'o@s aIm k'OInk 'aI w'0n@ b'i:; wID ju: kw'Iz l'aIk d'u: _:_:Tr'i:_!",
#   'question_raw': "-Hellz yeahh(: of course i'm qoinqq i wannah b with you quy's  like duhh<3",
#   'threat': False,
#   'txt_orig': 'Q: -Hellz yeahh(: of course i&#039;m qoinqq i wannah b with you quy&#039;s  like duhh<3<br>A: ahahaha!!!(: It wuzz funn!(: lmao<3'},
#  {'answer': 'Hahaha!!! Ohh cool wait are yuh thee april on twitter?! april2? haha yay! We beasts yo! haa',
#   'answer_as_sounds': 'Hahaha!!! Ohh cool wait are yuh thee april on twitter?! april2? haha yay! We beasts yo! haa',
#   'answer_raw': 'Hahaha!!! Ohh cool wait are yuh thee april on twitter?! april2? haha yay! We beasts yo! haa',
#   'labels': ['no', 'no', 'no'],
#   'question': "Haie MY' Namee _is_ Aprille tú HAHA peaple NAMED Aprille _Are ALWAYS Qool Loll",
#   'question_as_sounds': "h'eI maI n'eIm Iz 'eIprIl t'u:\n hA:h'A:\n p'i:p@L n'eImd 'eIprIl A@r- 'O:lweIz k'u:l\n l'0l\n",
#   'question_raw': 'Hey my name is April too! Haha. People named April are always cool. LOL.',
#   'threat': False,
#   'txt_orig': 'Q: Hey my name is April too! Haha. People named April are always cool. LOL.<br>A: Hahaha!!! Ohh cool wait are yuh thee april on twitter?! april2? haha yay! We beasts yo! haa'},
#  {'answer': 'Awwhhh!!!Thank yuh Jacob ur really nice!!! Might be my new bestie <33 Thank YUH SO MUCH!',
#   'answer_as_sounds': 'Awwhhh!!!Thank yuh Jacob ur really nice!!! Might be my new bestie <33 Thank YUH SO MUCH!',
#   'answer_raw': 'Awwhhh!!!Thank yuh Jacob ur really nice!!! Might be my new bestie <33 Thank YUH SO MUCH!',
#   'labels': ['no', 'no', 'no'],
#   'question': "Haie You're _an AMAZING Nyse ----------------------------------------------------------_And Sweete Gurle dot_xxx_domain dot_xxx_domain Pritty tú",
#   'question_as_sounds': "h'eI jU@r- a#n a#m'eIzIN n'aIs _:_:and sw'i:t g'3:l d'0t d'0t pr'It#i; t'u:\n",
#   'question_raw': "hey you're an amazing nice and sweet girl..pretty too!",
#   'threat': False,
#   'txt_orig': 'Q: hey you&#039;re an amazing nice and sweet girl..pretty too!<br>A: Awwhhh!!!Thank yuh Jacob ur really nice!!! Might be my new bestie <33 Thank YUH SO MUCH!'},
#  {'answer': 'Why thank yuh!',
#   'answer_as_sounds': 'Why thank yuh!',
#   'answer_raw': 'Why thank yuh!',
#   'labels': ['yes', 'yes', 'yes'],
#   'question': 'Haie _Why _You Suche a_ Biche',
#   'question_as_sounds': "h'eI\n w,aI ju: s'VtS a# b'ItS\n",
#   'question_raw': 'Hey. Why you such a bitch?',
#   'threat': True,
#   'txt_orig': 'Q: Hey. Why you such a bitch?<br>A: Why thank yuh!'},
#  {'answer': 'Heyy Marribbbiii!! lmao! iloveyuhhh muchooo moeee!!!;) are yuh goin tmrw?!',
#   'answer_as_sounds': 'Heyy Marribbbiii!! lmao! iloveyuhhh muchooo moeee!!!;) are yuh goin tmrw?!',
#   'answer_raw': 'Heyy Marribbbiii!! lmao! iloveyuhhh muchooo moeee!!!;) are yuh goin tmrw?!',
#   'labels': ['no', 'no', 'no'],
#   'question': 'UNKNOWN UNKNOWN UNKNOWN UNKNOWN ----------------------------------------------------------_3 UNKNOWN UNKNOWN',
#   'question_as_sounds': "h'eIji; a#br'Il@L k'oUl@n_:,Ekskl@m,eIS@n_:\n 'aIl@v,Ih@,Vu: _:_:Tr'i:_! m'VtSu:,oU _:'Ekskl@m,eIS@n_:\n",
#   'question_raw': 'Heyyy Abrilll(:!!! iloveyhuuu<3 muchooo!!',
#   'threat': False,
#   'txt_orig': 'Q: Heyyy Abrilll(:!!! iloveyhuuu<3 muchooo!!<br>A: Heyy Marribbbiii!! lmao! iloveyuhhh muchooo moeee!!!;) are yuh goin tmrw?!'},
#  {'answer': 'Im doing good thankyuh!!!Heyyy hbu?!',
#   'answer_as_sounds': 'Im doing good thankyuh!!!Heyyy hbu?!',
#   'answer_raw': 'Im doing good thankyuh!!!Heyyy hbu?!',
#   'labels': ['no', 'no', 'no'],
#   'question': "UNKNOWN UNKNOWN HOW' ♥_U DOIN UNKNOWN",
#   'question_as_sounds': "h'eIjjjji _:'Ekskl@m,eIS@n_:\n h,aU j'u: d'OIn _:'Ekskl@m,eIS@n_:\n",
#   'question_raw': 'heyyyyyy!!! how u doin!!!!!',
#   'threat': False,
#   'txt_orig': 'Q: heyyyyyy!!! how u doin!!!!!<br>A: Im doing good thankyuh!!!Heyyy hbu?!'},
#  {'answer': 'Heyy ghurrr!!! Wuzz upp!! haha nuttin much just busyy!! hbu ma?',
#   'answer_as_sounds': 'Heyy ghurrr!!! Wuzz upp!! haha nuttin much just busyy!! hbu ma?',
#   'answer_raw': 'Heyy ghurrr!!! Wuzz upp!! haha nuttin much just busyy!! hbu ma?',
#   'labels': ['no', 'no', 'no'],
#   'question': 'UNKNOWN UNKNOWN WATS UPPP UNKNOWN',
#   'question_as_sounds': "h'eIjjjjjji _:'Ekskl@m,eIS@n_: w'ats 'Vp\n _:'Ekskl@m,eIS@n_:,ast3r,Isk",
#   'question_raw': 'heyyyyyyyy!!!!wats up!?!?(*)-)',
#   'threat': False,
#   'txt_orig': 'Q: heyyyyyyyy!!!!wats up!?!?(*)-)<br>A: Heyy ghurrr!!! Wuzz upp!! haha nuttin much just busyy!! hbu ma?'},
#  {'answer': 'Heyy :D',
#   'answer_as_sounds': 'Heyy :D',
#   'answer_raw': 'Heyy :D',
#   'labels': ['no', 'no', 'no'],
#   'question': '_High Aprille UNKNOWN',
#   'question_as_sounds': "h'aI 'eIprIl _:'Ekskl@m,eIS@n_:\n",
#   'question_raw': 'Hi April!!!',
#   'threat': False,
#   'txt_orig': 'Q: Hi April!!!<br>A: Heyy :D'},
#  {'answer': 'Umm.. i think 2 bhut english is my first! im learnin french! ;d hbu?!',
#   'answer_as_sounds': 'Umm.. i think 2 bhut english is my first! im learnin french! ;d hbu?!',
#   'answer_raw': 'Umm.. i think 2 bhut english is my first! im learnin french! ;d hbu?!',
#   'labels': ['no', 'no', 'no'],
#   'question': "HOW' Menny LANGUAGES dû ♥_U SPEAC",
#   'question_as_sounds': "h,aU m'Eni; l'aNgwIdZI2z d'u: j'u: sp'i:k\n",
#   'question_raw': 'how many languages do u speak?',
#   'threat': False,
#   'txt_orig': 'Q: how many languages do u speak?<br>A: Umm.. i think 2 bhut english is my first! im learnin french! ;d hbu?!'},
#  {'answer': 'Who the hell are yuh!!! And who tha fuck is michael!?',
#   'answer_as_sounds': 'Who the hell are yuh!!! And who tha fuck is michael!?',
#   'answer_raw': 'Who the hell are yuh!!! And who tha fuck is michael!?',
#   'labels': ['yes', 'yes', 'no'],
#   'question': "HOW' OLDE _Are ♥_U UNKNOWN _and_ HOW' dû _You Knoah _Michael",
#   'question_as_sounds': "h,aU 'oUld A@r- j'u: ,Eks,Eks'Eks\n and h,aU d'u: ju: n'oU m'aIk@L\n",
#   'question_raw': 'how old are u ? And how do you know michael?',
#   'threat': True,
#   'txt_orig': 'Q: how old are u ? And how do you know michael?<br>A: Who the hell are yuh!!! And who tha fuck is michael!?'},
#  {'answer': 'Hmmm...personal? root word.. lol umm probss... bubbly  nice  honest(sumtyms)',
#   'answer_as_sounds': 'Hmmm...personal? root word.. lol umm probss... bubbly  nice  honest(sumtyms)',
#   'answer_raw': 'Hmmm...personal? root word.. lol umm probss... bubbly  nice  honest(sumtyms)',
#   'labels': ['no', 'no', 'no'],
#   'question': "HOW' _Would _You Discribe You're UNKNOWN",
#   'question_as_sounds': "h,aU wUd ju: dI2skr'aIb jU@r- p,3:s@n'alI2t#i\n",
#   'question_raw': 'How would you describe your personality?',
#   'threat': False,
#   'txt_orig': 'Q: How would you describe your personality?<br>A: Hmmm...personal? root word.. lol umm probss... bubbly  nice  honest(sumtyms)'},
#  {'answer': 'Myself Bubbly Funny?',
#   'answer_as_sounds': 'Myself Bubbly Funny?',
#   'answer_raw': 'Myself Bubbly Funny?',
#   'labels': ['no', 'no', 'no'],
#   'question': "HOW' _Would _You Discribe YOURSELF IN' ___________________________________________________________3 Wordes",
#   'question_as_sounds': "h,aU wUd ju: dI2skr'aIb jo@s'Elf In Tr'i:_! w'3:dz\n",
#   'question_raw': 'How would you describe yourself in 3 words?',
#   'threat': False,
#   'txt_orig': 'Q: How would you describe yourself in 3 words?<br>A: Myself Bubbly Funny?'},
#  {'answer': 'iLoveYou! Thanks alot! Bhut its alot 2 keep up wit! Wanna trade haha!',
#   'answer_as_sounds': 'iLoveYou! Thanks alot! Bhut its alot 2 keep up wit! Wanna trade haha!',
#   'answer_raw': 'iLoveYou! Thanks alot! Bhut its alot 2 keep up wit! Wanna trade haha!',
#   'labels': ['no', 'no', 'no'],
#   'question': "▪_i Lovee You're UNKNOWN",
#   'question_as_sounds': "'aI l'Vv jU@r- h'e@\n",
#   'question_raw': 'i love your hair.',
#   'threat': False,
#   'txt_orig': 'Q: i love your hair.<br>A: iLoveYou! Thanks alot! Bhut its alot 2 keep up wit! Wanna trade haha!'},
#  {'answer': 'NO no no! I Love youuu moreee<333 ;D haha!!',
#   'answer_as_sounds': 'NO no no! I Love youuu moreee<333 ;D haha!!',
#   'answer_raw': 'NO no no! I Love youuu moreee<333 ;D haha!!',
#   'labels': ['no', 'no', 'no'],
#   'question': '▪_i Lovee youu CHICA UNKNOWN',
#   'question_as_sounds': "'aI l'Vv j'aUu: tS'i:k@\n _:_:T'3:t#iTr'i:_!",
#   'question_raw': 'i love youu chica!<33',
#   'threat': False,
#   'txt_orig': 'Q: i love youu chica!<33<br>A: NO no no! I Love youuu moreee<333 ;D haha!!'},
#  {'answer': 'iFUCKINLoveyou!!!<33 xox ha!',
#   'answer_as_sounds': 'iFUCKINLoveyou!!!<33 xox ha!',
#   'answer_raw': 'iFUCKINLoveyou!!!<33 xox ha!',
#   'labels': ['no', 'no', 'no'],
#   'question': '▪_i Lovee UNKNOWN UNKNOWN',
#   'question_as_sounds': "'aI l'Vv j'aU@,V@,V@,u: ,Eks,Eks'Eks\n",
#   'question_raw': 'i love youuuuuuu (:',
#   'threat': False,
#   'txt_orig': 'Q: i love youuuuuuu (:<br>A: iFUCKINLoveyou!!!<33 xox ha!'},
#  {'answer': 'OMG! really?! cool thats so awesome! yeah i wanna learn more languages bhut french is already enuff 2 deal wit! ha',
#   'answer_as_sounds': 'OMG! really?! cool thats so awesome! yeah i wanna learn more languages bhut french is already enuff 2 deal wit! ha',
#   'answer_raw': 'OMG! really?! cool thats so awesome! yeah i wanna learn more languages bhut french is already enuff 2 deal wit! ha',
#   'labels': ['no', 'no', 'no'],
#   'question': "▪_i SPEAC ENGLISH UNKNOWN ----------------------------------------------------------_And a_ Littl ARABIC kuhs I'v BEEN _to Egypte a_ LOTTA Tymes Kohlen Deee",
#   'question_as_sounds': "'aI sp'i:k 'INglI2S fr'EnS _:_:and a# l'It#@L 'ara#b,Ik k'Vz aIv b,In tU 'i:dZIpt a# l'0t#@ t'aImz k'oUl@n d'i:;",
#   'question_raw': "i speak english frensh and a little arabic cuz i've been to egypt a lotta times :D",
#   'threat': False,
#   'txt_orig': 'Q: i speak english frensh and a little arabic cuz i&#039;ve been to egypt a lotta times :D<br>A: OMG! really?! cool thats so awesome! yeah i wanna learn more languages bhut french is already enuff 2 deal wit! ha'},
#  {'answer': 'Oh thats wht i think too! dnt be sorry hahaha! Silly goose',
#   'answer_as_sounds': 'Oh thats wht i think too! dnt be sorry hahaha! Silly goose',
#   'answer_raw': 'Oh thats wht i think too! dnt be sorry hahaha! Silly goose',
#   'labels': ['no', 'no', 'no'],
#   'question': 'İ THINC erh _Not UNKNOWN UNKNOWN',
#   'question_as_sounds': "aI T'INk '3:r- n,0t pr'It#i\n s'O:ri\n",
#   'question_raw': 'I think ur not pretty. Sorry.',
#   'threat': False,
#   'txt_orig': 'Q: I think ur not pretty. Sorry.<br>A: Oh thats wht i think too! dnt be sorry hahaha! Silly goose'},
#  {'answer': 'Hahah!! ohhkayy?!?! lol Wht do you call a deer with no eyes? I have no ideer! haha Classic  umm i suck at this haha',
#   'answer_as_sounds': 'Hahah!! ohhkayy?!?! lol Wht do you call a deer with no eyes? I have no ideer! haha Classic  umm i suck at this haha',
#   'answer_raw': 'Hahah!! ohhkayy?!?! lol Wht do you call a deer with no eyes? I have no ideer! haha Classic  umm i suck at this haha',
#   'labels': ['no', 'no', 'no'],
#   'question': "I'm Bórd _Can _You telle ME Sumthing UNKNOWN lool",
#   'question_as_sounds': "aIm b'o@d kan ju: t'El m,i:; s'VmTIN f'Vni\n l'u:l",
#   'question_raw': "i'm bored can you tell me something funny? lool",
#   'threat': False,
#   'txt_orig': 'Q: i&#039;m bored can you tell me something funny? lool<br>A: Hahah!! ohhkayy?!?! lol Wht do you call a deer with no eyes? I have no ideer! haha Classic  umm i suck at this haha'},
#  {'answer': 'IDKKK!!!GOD?! Not understndin this ? srry its like 3am hah',
#   'answer_as_sounds': 'IDKKK!!!GOD?! Not understndin this ? srry its like 3am hah',
#   'answer_raw': 'IDKKK!!!GOD?! Not understndin this ? srry its like 3am hah',
#   'labels': ['no', 'no', 'no'],
#   'question': "_If ♥_U LIVE FOREVER wat dû ♥_U LIVE FOR'",
#   'question_as_sounds': "If j'u: l'aIv fO@r'Ev3r- w'at d'u: j'u: l'aIv fO@\n",
#   'question_raw': 'IF U LIVE FOREVER WAT DO U LIVE FOR?????',
#   'threat': False,
#   'txt_orig': 'Q: IF U LIVE FOREVER WAT DO U LIVE FOR?????<br>A: IDKKK!!!GOD?! Not understndin this ? srry its like 3am hah'},
#  {'answer': 'Oh snap!! I would actually hug him first off ahah and say "Nigga where my weed go?" Hahaha jkjkjk i love him!! He is doin a great job!',
#   'answer_as_sounds': 'Oh snap!! I would actually hug him first off ahah and say "Nigga where my weed go?" Hahaha jkjkjk i love him!! He is doin a great job!',
#   'answer_raw': 'Oh snap!! I would actually hug him first off ahah and say "Nigga where my weed go?" Hahaha jkjkjk i love him!! He is doin a great job!',
#   'labels': ['no', 'no', 'no'],
#   'question': "_If _You COULD ¡_ASK barack O'bama WUNH QUESTION _What _Would it' B'",
# ...
#   'labels': ['no', 'no', 'no'],
#   'question': "Who's __The Moest OVERRATED ATHLETE",
#   'question_as_sounds': "h'u:z DI2; m'oUst ,oUv3r'eIt#Id 'aTli:t\n",
#   'question_raw': "Who's the most overrated athlete?",
#   'threat': False,
#   'txt_orig': 'Q: Who&#039;s the most overrated athlete?<br>A: Michael Jackson! haha wait wrong one  Michael Jordon i meant ahah'},
#  {'answer': 'idkk... mwauuuhhh!(:',
#   'answer_as_sounds': 'idkk... mwauuuhhh!(:',
#   'answer_raw': 'idkk... mwauuuhhh!(:',
#   'labels': ['no', 'no', 'no'],
#   'question': "Who's __The Prettiest PERSSON _You Knoah",
#   'question_as_sounds': "h'u:z DI2; prIt'Ist p'3:s@n ju: n'oU\n",
#   'question_raw': "who's the prettiest person you know?",
#   'threat': False,
#   'txt_orig': 'Q: who&#039;s the prettiest person you know?<br>A: idkk... mwauuuhhh!(:'},
#  {'answer': "I do not judge gyrls im not bi or a lezzboo!! K thanks'",
#   'answer_as_sounds': "I do not judge gyrls im not bi or a lezzboo!! K thanks'",
#   'answer_raw': "I do not judge gyrls im not bi or a lezzboo!! K thanks'",
#   'labels': ['no', 'no', 'no'],
#   'question': "Who's __The SEXIEST WOMAN ALIVE",
#   'question_as_sounds': "h'u:z DI2; s'EksI;@st w'Um@n a#l'aIv\n",
#   'question_raw': "Who's the sexiest woman alive?",
#   'threat': False,
#   'txt_orig': "Q: Who&#039;s the sexiest woman alive?<br>A: I do not judge gyrls im not bi or a lezzboo!! K thanks'"},
#  {'answer': '@JustinBSource 4 sure LMAO!',
#   'answer_as_sounds': '@JustinBSource 4 sure LMAO!',
#   'answer_raw': '@JustinBSource 4 sure LMAO!',
#   'labels': ['no', 'yes', 'no'],
#   'question': "Who's __The SMARTEST PERSSON _You Knoah",
#   'question_as_sounds': "h'u:z DI2; sm'A@t#@st p'3:s@n ju: n'oU\n",
#   'question_raw': "Who's the smartest person you know?",
#   'threat': False,
#   'txt_orig': 'Q: Who&#039;s the smartest person you know?<br>A: @JustinBSource 4 sure LMAO!'},
#  {'answer': 'Well im not following anything and really BANDWAGON?!?! soo oldd!! Its more like trend these days! Justin Bieber* Idiot! Cnt spell!',
#   'answer_as_sounds': 'Well im not following anything and really BANDWAGON?!?! soo oldd!! Its more like trend these days! Justin Bieber* Idiot! Cnt spell!',
#   'answer_raw': 'Well im not following anything and really BANDWAGON?!?! soo oldd!! Its more like trend these days! Justin Bieber* Idiot! Cnt spell!',
#   'labels': ['yes', 'yes', 'yes'],
#   'question': '_Why dû ♥_U folow __The BANDWAGON Formspring UNKNOWN WHATS NEXT Gaie Justyn UNKNOWN',
#   'question_as_sounds': "w,aI d'u: j'u: f'0loU DI2; b'andwag@n\n f'O@msprIN\n tw'It#3\n w,Vts n'Ekst g'eI dZ'VstIn b'eIb3\n",
#   'question_raw': "Why do u follow the bandwagon? Formspring. Twitter. What's next gay Justin beiber.",
#   'threat': True,
#   'txt_orig': 'Q: Why do u follow the bandwagon? Formspring. Twitter. What&#039;s next gay Justin beiber.<br>A: Well im not following anything and really BANDWAGON?!?! soo oldd!! Its more like trend these days! Justin Bieber* Idiot! Cnt spell!'},
#  {'answer': 'Umm... he has a bigga heart than you will EVER have so before you start to hate on a 16yr old that you obviously are addicted to  get your facts straight kay?',
#   'answer_as_sounds': 'Umm... he has a bigga heart than you will EVER have so before you start to hate on a 16yr old that you obviously are addicted to  get your facts straight kay?',
#   'answer_raw': 'Umm... he has a bigga heart than you will EVER have so before you start to hate on a 16yr old that you obviously are addicted to  get your facts straight kay?',
#   'labels': ['no', 'yes', 'no'],
#   'question': "_Why dû ♥_U Lieck LI'L QIDS Lieck Justyn UNKNOWN",
#   'question_as_sounds': "w,aI d'u: j'u: l'aIk l'Il k'Idz l'aIk dZ'VstIn b'eIb3\n",
#   'question_raw': 'Why do u like lil kids like Justin Beiber?',
#   'threat': False,
#   'txt_orig': 'Q: Why do u like lil kids like Justin Beiber?<br>A: Umm... he has a bigga heart than you will EVER have so before you start to hate on a 16yr old that you obviously are addicted to  get your facts straight kay?'},
#  {'answer': 'Umm.. u kno wht WTF ever! STOP HATIN!',
#   'answer_as_sounds': 'Umm.. u kno wht WTF ever! STOP HATIN!',
#   'answer_raw': 'Umm.. u kno wht WTF ever! STOP HATIN!',
#   'labels': ['no', 'no', 'yes'],
#   'question': "_Why dû ♥_U Lieck _that Beiber kidd SO mutch He's llame ----------------------------------------------------------_And Can't Syng",
#   'question_as_sounds': "w,aI d'u: j'u: l'aIk Dat b'eIb3r- k'Id s,oU m'VtS\n hi:z l'eIm _:_:and k'ant s'IN\n",
#   'question_raw': "Why do u like that beiber kid so much. He's lame and can't sing.",
#   'threat': False,
#   'txt_orig': 'Q: Why do u like that beiber kid so much. He&#039;s lame and can&#039;t sing.<br>A: Umm.. u kno wht WTF ever! STOP HATIN!'},
#  {'answer': '- Marryyyyy!!!!??/ LOL! itss yuhh boo!!! Hahaha Noo durr suckkaaa!!! Nahhh i loveee yuhhhh mooOee!!!',
#   'answer_as_sounds': '- Marryyyyy!!!!??/ LOL! itss yuhh boo!!! Hahaha Noo durr suckkaaa!!! Nahhh i loveee yuhhhh mooOee!!!',
#   'answer_raw': '- Marryyyyy!!!!??/ LOL! itss yuhh boo!!! Hahaha Noo durr suckkaaa!!! Nahhh i loveee yuhhhh mooOee!!!',
#   'labels': ['no', 'no', 'no'],
#   'question': "UNKNOWN UNKNOWN doodh I'm IN' UNKNOWN backround UNKNOWN Kohlen Deee UNKNOWN ----------------------------------------------------------_3 UNKNOWN",
#   'question_as_sounds': "w'oUA:\n l'Iki:; d'u:d aIm In j'aUhr@ b'akraUnd _:'Ekskl@m,eIS@n_:\n k'oUl@n d'i:; 'O:soUm,i:\n _:_:Tr'i:_! 'IlI2bI;i\n",
#   'question_raw': "-woaahhhhhh! Likee dude i'm in youhr backround!!! :D AWESOMEEEE! <3 ilybbyy(:",
#   'threat': False,
#   'txt_orig': 'Q: -woaahhhhhh! Likee dude i&#039;m in youhr backround!!! :D AWESOMEEEE! <3 ilybbyy(:<br>A: - Marryyyyy!!!!??/ LOL! itss yuhh boo!!! Hahaha Noo durr suckkaaa!!! Nahhh i loveee yuhhhh mooOee!!!'},
#  {'answer': 'Hahaha i think i would! I always do thee same shizz all thee tyme so yes i would hbu ?! ;D',
#   'answer_as_sounds': 'Hahaha i think i would! I always do thee same shizz all thee tyme so yes i would hbu ?! ;D',
#   'answer_raw': 'Hahaha i think i would! I always do thee same shizz all thee tyme so yes i would hbu ?! ;D',
#   'labels': ['no', 'no', 'no'],
#   'question': "_Would ♥_U EVER GO' Bungee JUMPING Lieck Justyn dydd",
#   'question_as_sounds': "wUd j'u: 'Ev3r- g,oU b'VndZi:; dZ'VmpIN l'aIk dZ'VstIn d'Id\n",
#   'question_raw': 'would u ever go bungee jumping like justin did?',
#   'threat': False,
#   'txt_orig': 'Q: would u ever go bungee jumping like justin did?<br>A: Hahaha i think i would! I always do thee same shizz all thee tyme so yes i would hbu ?! ;D'},
#  {'answer': 'Not a guy! haha maybe a cheerleader haha jkjk!',
#   'answer_as_sounds': 'Not a guy! haha maybe a cheerleader haha jkjk!',
#   'answer_raw': 'Not a guy! haha maybe a cheerleader haha jkjk!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Would _You Wrather BE a_ FAMOUS MUSICIAN or a_ FAMOUS UNKNOWN',
#   'question_as_sounds': "wUd ju: r'aD3r- bi:; a# f'eIm@s mju:s'IS@n _:_:O@r a# f'eIm@s 'akt3\n",
#   'question_raw': 'Would you rather be a famous musician or a famous actor?',
#   'threat': False,
#   'txt_orig': 'Q: Would you rather be a famous musician or a famous actor?<br>A: Not a guy! haha maybe a cheerleader haha jkjk!'},
#  {'answer': "Werewolf -AkA-  Jacob's Pride lol! His good part! lol",
#   'answer_as_sounds': "Werewolf -AkA-  Jacob's Pride lol! His good part! lol",
#   'answer_raw': "Werewolf -AkA-  Jacob's Pride lol! His good part! lol",
#   'labels': ['no', 'no', 'no'],
#   'question': '_Would _You Wrather BE a_ Vampire or a_ WEREWOLF',
#   'question_as_sounds': "wUd ju: r'aD3r- bi:; a# v'ampaI@r- _:_:O@r a# w'i@3wUlf\n",
#   'question_raw': 'Would you rather be a vampire or a werewolf?',
#   'threat': False,
#   'txt_orig': "Q: Would you rather be a vampire or a werewolf?<br>A: Werewolf -AkA-  Jacob's Pride lol! His good part! lol"},
#  {'answer': 'Zombie 4sho!',
#   'answer_as_sounds': 'Zombie 4sho!',
#   'answer_raw': 'Zombie 4sho!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Would _You Wrather BE a_ Zomby or a_ UNKNOWN',
#   'question_as_sounds': "wUd ju: r'aD3r- bi:; a# z'0mbi; _:_:O@r a# m'Vmi\n",
#   'question_raw': 'Would you rather be a zombie or a mummy?',
#   'threat': False,
#   'txt_orig': 'Q: Would you rather be a zombie or a mummy?<br>A: Zombie 4sho!'},
#  {'answer': 'Famous(: Bhut im ME 4 rite now!',
#   'answer_as_sounds': 'Famous(: Bhut im ME 4 rite now!',
#   'answer_raw': 'Famous(: Bhut im ME 4 rite now!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Would _You Wrather BE RICHE or FAMOUS',
#   'question_as_sounds': "wUd ju: r'aD3r- bi:; r'ItS _:_:O@r f'eIm@s\n",
#   'question_raw': 'Would you rather be rich or famous?',
#   'threat': False,
#   'txt_orig': 'Q: Would you rather be rich or famous?<br>A: Famous(: Bhut im ME 4 rite now!'},
#  {'answer': 'Both? LOL! jk',
#   'answer_as_sounds': 'Both? LOL! jk',
#   'answer_raw': 'Both? LOL! jk',
#   'labels': ['no', 'no', 'no'],
#   'question': "_Would _You Wrather Deitte a_ lott _Of Diff'rent peaple or BE IN' a_ COMMITTED RELATIONSHIP",
#   'question_as_sounds': "wUd ju: r'aD3r- d'eIt a# l'0t Vv d'Ifr@nt p'i:p@L _:_:O@r bi:; In a# k@m'It#I2d rI2l'eIS@nS,Ip\n",
#   'question_raw': 'Would you rather date a lot of different people  or be in a committed relationship?',
#   'threat': False,
#   'txt_orig': 'Q: Would you rather date a lot of different people  or be in a committed relationship?<br>A: Both? LOL! jk'},
#  {'answer': 'SLEEP LATE!!Duh!',
#   'answer_as_sounds': 'SLEEP LATE!!Duh!',
#   'answer_raw': 'SLEEP LATE!!Duh!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Would _You Wrather _Get _Up Urli or Sleap leit',
#   'question_as_sounds': "wUd ju: r'aD3r- gEt ,Vp '3:li; _:_:O@r sl'i:p l'eIt\n",
#   'question_raw': 'Would you rather get up early or sleep late?',
#   'threat': False,
#   'txt_orig': 'Q: Would you rather get up early or sleep late?<br>A: SLEEP LATE!!Duh!'},
#  {'answer': 'JET!!(: Hate boats! Worst experience ever was on a boat! Never again!',
#   'answer_as_sounds': 'JET!!(: Hate boats! Worst experience ever was on a boat! Never again!',
#   'answer_raw': 'JET!!(: Hate boats! Worst experience ever was on a boat! Never again!',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Would _You Wrather Oan a_ LUXURY yot or a_ privat JETT',
#   'question_as_sounds': "wUd ju: r'aD3r- 'oUn a# l'VgZu:3r-i; j'0t _:_:O@r a# pr'aIv@t dZ'Et\n",
#   'question_raw': 'Would you rather own a luxury yacht or a private jet?',
#   'threat': False,
#   'txt_orig': 'Q: Would you rather own a luxury yacht or a private jet?<br>A: JET!!(: Hate boats! Worst experience ever was on a boat! Never again!'},
#  {'answer': 'Pool',
#   'answer_as_sounds': 'Pool',
#   'answer_raw': 'Pool',
#   'labels': ['no', 'no', 'no'],
#   'question': "_Would _You Wrather Swimme IN' a_ puhl or __The Ocian",
#   'question_as_sounds': "wUd ju: r'aD3r- sw'Im In a# p'u:l _:_:O@r DI2; 'oUS@n\n",
#   'question_raw': 'Would you rather swim in a pool or the ocean?',
#   'threat': False,
#   'txt_orig': 'Q: Would you rather swim in a pool or the ocean?<br>A: Pool'},
#  {'answer': 'None! haha',
#   'answer_as_sounds': 'None! haha',
#   'answer_raw': 'None! haha',
#   'labels': ['no', 'no', 'no'],
#   'question': '_Would _You Wrather Worc _At a_ LARGE COMPANY or a_ SMALL UNKNOWN',
#   'question_as_sounds': "wUd ju: r'aD3r- w'3:k at a# l'A@dZ k'Vmp@ni; _:_:O@r a# sm'O:l w,Vn\n",
#   'question_raw': 'Would you rather work at a large company or a small one?',
#   'threat': False,
#   'txt_orig': 'Q: Would you rather work at a large company or a small one?<br>A: None! haha'},
#  {'answer': 'Ohh man i bet its tha shit!! Ohhkayy!(: be safe have fun!! <33',
#   'answer_as_sounds': 'Ohh man i bet its tha shit!! Ohhkayy!(: be safe have fun!! <33',
#   'answer_raw': 'Ohh man i bet its tha shit!! Ohhkayy!(: be safe have fun!! <33',
#   'labels': ['no', 'no', 'no'],
#   'question': "YAY' IT'Z Diff'rent _From Warme CALLIE UNKNOWN Qool Kohlen Deee UNKNOWN GTG KNAU Kohlen GONNA Maeght _Some frends ▪_i a_ PHEW MINUTES Loll dot_xxx_domain BHAI UNKNOWN xx",
#   'question_as_sounds': "j'eI Itz d'Ifr@nt frVm w'O@m k'ali; _:_:b,Vts k'u:l k'oUl@n d'i:; w'i:;i:l dZ,i:t,i:dZ'i:; n'aU k'oUl@n g'0n@ m'i:t s,Vm fr'Endz 'aI a# fj'u: m'InIts l'0l d'0t b'aI ,Eks,Eks'Eks\n r,oUm@n_tw'Ent#i_!",
#   'question_raw': "yea it's different from warm cali  but's cool :D weeeell gtg now :| gonna meet some friends i a few minutes lol.bye :] xx",
#   'threat': False,
#   'txt_orig': 'Q: yea it&#039;s different from warm cali  but&#039;s cool :D weeeell gtg now :| gonna meet some friends i a few minutes lol.bye :] xx<br>A: Ohh man i bet its tha shit!! Ohhkayy!(: be safe have fun!! <33'},
#  {'answer': 'Yehh hahaha...idk.its weird..Boys r Boys So Im Me!!!alone hahah',
#   'answer_as_sounds': 'Yehh hahaha...idk.its weird..Boys r Boys So Im Me!!!alone hahah',
#   'answer_raw': 'Yehh hahaha...idk.its weird..Boys r Boys So Im Me!!!alone hahah',
#   'labels': ['no', 'no', 'no'],
#   'question': "YAY' _You ^_Ar Ryte HOW' _Should __The 1_ B' ▪_i _Have Knoah Bf tú UNKNOWN",
#   'question_as_sounds': "j'eI ju: 'A@r- r'aIt\n h,aU S,Ud DI2; w'Vn_! b'i:\n 'aI hav n'oU b,i:;'Ef t'u: _:'Ekskl@m,eIS@n_:\n",
#   'question_raw': 'yeh you r right... how should the 1 be?? i have no bf too!:)',
#   'threat': False,
#   'txt_orig': 'Q: yeh you r right... how should the 1 be?? i have no bf too!:)<br>A: Yehh hahaha...idk.its weird..Boys r Boys So Im Me!!!alone hahah'},
#  {'answer': 'Hahaha(: ight',
#   'answer_as_sounds': 'Hahaha(: ight',
#   'answer_raw': 'Hahaha(: ight',
#   'labels': ['no', 'no', 'no'],
#   'question': 'UNKNOWN Mateh Rinna luvs Jb here> UNKNOWN ¡_ASK ME ANYTHING UNKNOWN UNKNOWN',
#   'question_as_sounds': "j'u:u:,oU m'eIt r'In@ l'Vvz dZ,eIb'i:; h'i@3\n h'eIhi; 'aask m,i:; 'EnI2T,IN ,Eks,Eks'Eks\n ,Eks,Eks'Eks\n",
#   'question_raw': 'Yooooo mate   RinnaLovesJB here. heyhey  ask me anything ! (:',
#   'threat': False,
#   'txt_orig': 'Q: Yooooo mate   RinnaLovesJB here. heyhey  ask me anything ! (:<br>A: Hahaha(: ight'},
#  {'answer': 'Umm...im truly sorry! bhut i didnt mean it in ANYWAY like u obviously got offended by!and i said it wasnt funny! So before you get all angry nd shit ill delete that tweet! Kthanks btw RIP ur daddy and brother',
#   'answer_as_sounds': 'Umm...im truly sorry! bhut i didnt mean it in ANYWAY like u obviously got offended by!and i said it wasnt funny! So before you get all angry nd shit ill delete that tweet! Kthanks btw RIP ur daddy and brother',
#   'answer_raw': 'Umm...im truly sorry! bhut i didnt mean it in ANYWAY like u obviously got offended by!and i said it wasnt funny! So before you get all angry nd shit ill delete that tweet! Kthanks btw RIP ur daddy and brother',
#   'labels': ['no', 'no', 'yes'],
#   'question': "_You Kneed or _Should DELETE _that UNKNOWN TWEET _Not Phunny _At Aule _You Knoah HOW' Menny peaple Dyde _that Daie _including MY' FATHER ----------------------------------------------------------_And BROTHER",
#   'question_as_sounds': "ju: n'i:d _:_:O@r S,Ud dI2l'i:t Dat n'aInh'Vndr@dIl'Ev@n_! tw'i:t\n n,0t f'Vni; at 'O:l\n ju: n'oU h,aU m'Eni; p'i:p@L d'aId Dat d'eI Inkl'u:dIN maI f'A:D3r- _:_:and br'VD3r-",
#   'question_raw': 'you need or should delete that 911 tweet. Not funny at all! you know how many people died that day including my father and brother',
#   'threat': False,
#   'txt_orig': 'Q: you need or should delete that 911 tweet. Not funny at all! you know how many people died that day including my father and brother<br>A: Umm...im truly sorry! bhut i didnt mean it in ANYWAY like u obviously got offended by!and i said it wasnt funny! So before you get all angry nd shit ill delete that tweet! Kthanks btw RIP ur daddy and brother'},
#  {'answer': 'Thank yuh soo muchh!!!;D Im likin yurs 2 Mwah!',
#   'answer_as_sounds': 'Thank yuh soo muchh!!!;D Im likin yurs 2 Mwah!',
#   'answer_raw': 'Thank yuh soo muchh!!!;D Im likin yurs 2 Mwah!',
#   'labels': ['no', 'no', 'no'],
#   'question': "You're atitude _is_ SO phun UNKNOWN",
#   'question_as_sounds': "jU@r- 'at#I2t,u:d Iz s,oU f'Vn ,Eks,Eks'Eks\n",
#   'question_raw': 'your attitude is so fun :)',
#   'threat': False,
#   'txt_orig': 'Q: your attitude is so fun :)<br>A: Thank yuh soo muchh!!!;D Im likin yurs 2 Mwah!'}]

# %% [markdown]
# ### Sanity check
# Round-tripping a common sentence should return the same sentence

# %%
common_words = "hello world how are you today? My oncle is rich"
graphs_phons = graphemes_to_phonemes(common_words.split())

# let's "for" it to have a detailed report on failures: 
common_words_back = []
for _, sound in graphs_phons:
    try:
        common_words_back.append(mw.sound_to_word(sound))
    except Exception as e:
        print(e)
        common_words_back.append('UNKNOWN')
print("common words = {}".format(common_words))
print("graphs_phons = {}".format(graphs_phons))
print("common_words_back = {}".format(common_words_back))
# Out:
# common words = hello world how are you today? My oncle is rich
# graphs_phons = [('hello', "h@l'oU"), ('world', "w'3:ld"), ('how', 'h,aU'), ('are', 'A@r-'), ('you', 'ju:'), ('today?', "t@d'eI\n"), ('My', 'maI'), ('oncle', "'0Nk@L"), ('is', 'Iz'), ('rich', "r'ItS")]
# common_words_back = ['HELLO', '_World', "HOW'", '_Are', '_You', 'today!', "MY'", 'Oncle', '_is_', 'RICHE']

# %%
mw.sound_to_word("r'ItS")
# Out:
# 'RICHE'

# %%
check_output(["speak", "-q", "-x",'-v', 'en-us',"RICHE"]).decode('utf-8')
# Out:
# " r'ItS\n"

# %%
all_sounds = mw.sounds_dict.keys()

# %%
print("We have {} words in vocabulary, {} sounds".format(len(mw.model.vocab), len(all_sounds)))
# Out:
# We have 3000000 words in vocabulary, 2188943 sounds

# %%
[e for e in all_of_them if e["threat"]]
# Out:
# [{'answer': 'UM excuse yuh? HE IS NOT!! Ur a fuckin idiot! Kay? good',
#   'answer_as_sounds': 'UM excuse yuh? HE IS NOT!! Ur a fuckin idiot! Kay? good',
#   'answer_raw': 'UM excuse yuh? HE IS NOT!! Ur a fuckin idiot! Kay? good',
#   'labels': ['yes', 'yes', 'yes'],
#   'question': "phuck Justyn UNKNOWN He's a_ FUCKING Fag",
#   'question_as_sounds': "f'Vk dZ'VstIn b'i:b3\n hi:z a# f'VkIN f'ag",
#   'question_raw': "Fuck Justin bieber. He's a fucking fag",
#   'threat': True,
#   'txt_orig': 'Q: Fuck Justin bieber. He&#039;s a fucking fag<br>A: UM excuse yuh? HE IS NOT!! Ur a fuckin idiot! Kay? good'},
#  {'answer': 'and its also funny how u stalked my whole twitter! Nice goin! BITCH!',
#   'answer_as_sounds': 'and its also funny how u stalked my whole twitter! Nice goin! BITCH!',
#   'answer_raw': 'and its also funny how u stalked my whole twitter! Nice goin! BITCH!',
#   'labels': ['no', 'yes', 'yes'],
#   'question': "Hahah Phunny HOW' ♥_U DEFEND _that Beiber kidd",
#   'question_as_sounds': "h'ah@\n f'Vni; h,aU j'u: dI2f'End Dat b'eIb3r- k'Id\n",
#   'question_raw': 'Hahah. Funny how u defend that beiber kid.',
#   'threat': True,
#   'txt_orig': 'Q: Hahah. Funny how u defend that beiber kid.<br>A: &amp; its also funny how u stalked my whole twitter! Nice goin! BITCH!'},
#  {'answer': 'Why thank yuh!',
#   'answer_as_sounds': 'Why thank yuh!',
#   'answer_raw': 'Why thank yuh!',
#   'labels': ['yes', 'yes', 'yes'],
#   'question': 'Haie _Why _You Suche a_ Biche',
#   'question_as_sounds': "h'eI\n w,aI ju: s'VtS a# b'ItS\n",
#   'question_raw': 'Hey. Why you such a bitch?',
#   'threat': True,
#   'txt_orig': 'Q: Hey. Why you such a bitch?<br>A: Why thank yuh!'},
#  {'answer': 'Who the hell are yuh!!! And who tha fuck is michael!?',
#   'answer_as_sounds': 'Who the hell are yuh!!! And who tha fuck is michael!?',
#   'answer_raw': 'Who the hell are yuh!!! And who tha fuck is michael!?',
#   'labels': ['yes', 'yes', 'no'],
#   'question': "HOW' OLDE _Are ♥_U UNKNOWN _and_ HOW' dû _You Knoah _Michael",
#   'question_as_sounds': "h,aU 'oUld A@r- j'u: ,Eks,Eks'Eks\n and h,aU d'u: ju: n'oU m'aIk@L\n",
#   'question_raw': 'how old are u ? And how do you know michael?',
#   'threat': True,
#   'txt_orig': 'Q: how old are u ? And how do you know michael?<br>A: Who the hell are yuh!!! And who tha fuck is michael!?'},
#  {'answer': 'Now how the fuck am i suppose to remember that? Weirdo! maybe it was ur moms dick? lOL!',
#   'answer_as_sounds': 'Now how the fuck am i suppose to remember that? Weirdo! maybe it was ur moms dick? lOL!',
#   'answer_raw': 'Now how the fuck am i suppose to remember that? Weirdo! maybe it was ur moms dick? lOL!',
#   'labels': ['yes', 'yes', 'no'],
#   'question': "_What \uf0b7_Was You're _Favorite PTOI _to Pley withh _as a_ Childe",
#   'question_as_sounds': "w,Vt wVz jU@r- f'eIv@-rI2t t'OI tU pl'eI wID az a# tS'aIld\n",
#   'question_raw': 'What was your favorite toy to play with as a child?',
#   'threat': True,
#   'txt_orig': 'Q: What was your favorite toy to play with as a child?<br>A: Now how the fuck am i suppose to remember that? Weirdo! maybe it was ur moms dick? lOL!'},
#  {'answer': 'im not quite sure! ill tell ya when i find out! I promise(:',
#   'answer_as_sounds': 'im not quite sure! ill tell ya when i find out! I promise(:',
#   'answer_raw': 'im not quite sure! ill tell ya when i find out! I promise(:',
#   'labels': ['yes', 'yes', 'yes'],
#   'question': "_WHO DECIDED _to Teike a_ Shitte _On You're Faiss",
#   'question_as_sounds': "h,u: dI2s'aIdId tU t'eIk a# S'It ,0n jU@r- f'eIs\n",
#   'question_raw': 'who decided to take a shit on your face?',
#   'threat': True,
#   'txt_orig': 'Q: who decided to take a shit on your face?<br>A: im not quite sure! ill tell ya when i find out! I promise(:'},
#  {'answer': 'Well im not following anything and really BANDWAGON?!?! soo oldd!! Its more like trend these days! Justin Bieber* Idiot! Cnt spell!',
#   'answer_as_sounds': 'Well im not following anything and really BANDWAGON?!?! soo oldd!! Its more like trend these days! Justin Bieber* Idiot! Cnt spell!',
#   'answer_raw': 'Well im not following anything and really BANDWAGON?!?! soo oldd!! Its more like trend these days! Justin Bieber* Idiot! Cnt spell!',
#   'labels': ['yes', 'yes', 'yes'],
#   'question': '_Why dû ♥_U folow __The BANDWAGON Formspring UNKNOWN WHATS NEXT Gaie Justyn UNKNOWN',
#   'question_as_sounds': "w,aI d'u: j'u: f'0loU DI2; b'andwag@n\n f'O@msprIN\n tw'It#3\n w,Vts n'Ekst g'eI dZ'VstIn b'eIb3\n",
#   'question_raw': "Why do u follow the bandwagon? Formspring. Twitter. What's next gay Justin beiber.",
#   'threat': True,
#   'txt_orig': 'Q: Why do u follow the bandwagon? Formspring. Twitter. What&#039;s next gay Justin beiber.<br>A: Well im not following anything and really BANDWAGON?!?! soo oldd!! Its more like trend these days! Justin Bieber* Idiot! Cnt spell!'}]

# %%
all_of_them[0]
# Out:
# {'answer': '</3 ? haha jk! <33',
#  'labels': ['no', 'no', 'no'],
#  'question': '<3',
#  'threat': False,
#  'txt_orig': 'Q: <3<br>A: </3 ? haha jk! <33'}

# %%
import gensim 
import bisect 
import numpy as np
from typing import List, Dict
import shelve

data_dir = "./data"

class ModelWrapper():
        
    default_shelf_filename = '{}/shelf_whole_google_news.shelf'.format(data_dir)
        
    def __init__(self, m, sounds_dict = None):
        if m is None:
            print("Loading model...")
            self.model = gensim.models.word2vec.KeyedVectors.load_word2vec_format('{}/GoogleNews-vectors-negative300.bin.gz'.format(data_dir), binary=True)
            print("Model succesfully loaded")
        else:
            print("[init] Model provided. If you want me to FORCE re-load it, call ModelWrapper's constructor with 'None'")
            self.model = m            
        # sort all the words in the model, so that we can auto-complete queries quickly
        print("Sort all the words in the model, so that we can auto-complete queries quickly...")
        self.orig_words = [gensim.utils.to_unicode(word) for word in self.model.index2word]
        indices = [i for i, _ in sorted(enumerate(self.orig_words), key=lambda item: item[1].lower())]
        self.all_words = [self.orig_words[i].lower() for i in indices]  # lowercased, sorted as lowercased
        self.orig_words = [self.orig_words[i] for i in indices]  # original letter casing, but sorted as if lowercased
        
        # sounds dictionary 
        if sounds_dict is None:
            print("Loading default sounds dictionary from '{}'...".format(self.default_shelf_filename))
            self.sounds_dict = shelve.open(self.default_shelf_filename, flag='r')  
            print("Sounds dictionary succesfully loaded")
        else:
            self.sounds_dict = sounds_dict
    
        
        
        
    def suggest(self, term):
        """
        For a given prefix, return 10 words that exist in the model start start with that prefix
        """
        prefix = gensim.utils.to_unicode(term).strip().lower()
        count = 10
        pos = bisect.bisect_left(self.all_words, prefix)
        result = self.orig_words[pos: pos + count]
        logger.info("suggested %r: %s" % (prefix, result))
        return result      
    
    def most_similar(self, positive, negative):
        """
            positive: an array of positive words
            negative: an array of negative words 
        """                
        try:
            result = self.model.most_similar(
                positive=[word.strip() for word in positive if word],
                negative=[word.strip() for word in negative if word],
                topn=5)
        except:
            result = []
        logger.info("similars for %s vs. %s: %s" % (positive, negative, result))
        return {'similars': result}    
    
    def vec_repr(self, word):
        """
            If 'word' belongs in the vocabulary, returns its 
            word2vec representation. Otherwise returns a vector of 0's
            of the same length of the other words. 
        """
        try:
            return self.model.word_vec(word)
        except KeyError:
            logger.debug("'{}' not in Model. Returning [0]'s vector.".format(word))
            return np.zeros(self.model.vector_size)
        
    def sound_to_word(self, a_sound: str) -> str:
        return self.sounds_dict[a_sound]
    # self.sound_repr(a_sound)["word"]

    def sound_to_vec(self, a_sound: str) -> str:
        return self.vec_repr(self.sound_to_word(a_sound))

    def sound_repr(self, a_sound: str) -> Dict:
        # w = self.sounds_dict[a_sound]
        return {'word': self.sound_to_word(a_sound), 'vec': self.sound_to_vec(a_sound)}

# %%
mw = ModelWrapper(model)
model = mw.model # just cache in case I re-call this cell
# Out:
# Loading model...
# Model succesfully loaded
# Sort all the words in the model, so that we can auto-complete queries quickly...
# Loading default sounds dictionary from 'shelf_from0_for2999999.shelf'...
# Sounds dictionary succesfully loaded

# %%
from joblib import Parallel, delayed
import multiprocessing
    
# what are your inputs, and what operation do you want to 
# perform on each input. For example...
inputs = range(10) 
def processInput(i):
    return i * i

num_cores = multiprocessing.cpu_count()
print("You have {} cores".format(num_cores))
# Out:
# You have 8 cores

# %%
inputs2 = list(range(1000)) 
orig_inputs2 = inputs2
def processInput2(i):
    diff_l = [a_i - b_i for a_i, b_i in zip(inputs2, orig_inputs2)]
    nonnon = [i for i, e in enumerate(diff_l) if e != 0]
    if len(nonnon) > 0:
        print("[i = {}] indexes that changed = {}".format(i, nonnon)) 
    r = inputs2[i]
    inputs2[i] = -1 
    return r

# results = Parallel(n_jobs=num_cores)(delayed(processInput)(i) for i in inputs)
# results 
results = Parallel(n_jobs=num_cores)(delayed(processInput2)(i) for i,_ in enumerate(inputs2))
# print("results = {}".format(results)) 
# print("inputs2 = {}".format(inputs2))

# %%
inputs2 = list(range(3)) 
inputs2 - inputs2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-207-5c8234aac248> in <module>()
#       1 inputs2 = list(range(3))
# ----> 2 inputs2 - inputs2
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
[3, 4, 5] - [6, 7, 8]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-f3a1fe6ddde2> in <module>()
# ----> 1 [3, 4, 5] - [6, 7, 8]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
inputs2[3] = -44

# %%
inputs2
# Out:
# [0, 1, 2, -44, 4, 5, 6, 7, 8, 9]
